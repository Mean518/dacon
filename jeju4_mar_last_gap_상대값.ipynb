# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset_min.csv',index_col=0)
submission = pd.read_csv('submission_min.csv',index_col=0)

# %%
last_mar=dataset[dataset['사용년']==0][dataset['사용월']==3]
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
last_may=dataset[dataset['사용년']==0][dataset['사용월']==5]
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
last_april=dataset[dataset['사용년']==0][dataset['사용월']==4]
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
this_mar=dataset[dataset['사용년']==1][dataset['사용월']==3]
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
print(len(last_mar))
print(len(this_mar))
# Out:
# 630
# 609

# %%
mar_gap = pd.merge(last_mar,this_mar,on=['사용월','사용지역_도1','업종명_대분류1','업종명1'])

# %%
mar_gap
# Out:
#      사용년_x  사용월  사용지역_도1  업종명_대분류1  업종명1        이용금액_x  사용년_y        이용금액_y
# 0        0    3        0         0     0  215161897702      1  147494192925
# 1        0    3        0         0     6   46294820641      1   33691383982
# 2        0    3        0         0     7   20570214952      1   18715095314
# 3        0    3        0         0     9   20476576751      1   13327780001
# 4        0    3        0         0    11   11259256477      1    7348439049
# ..     ...  ...      ...       ...   ...           ...    ...           ...
# 600      0    3       16        11    21      37542532      1      19025100
# 601      0    3       16        12    26      21802000      1      12071000
# 602      0    3       16        12    33       7038000      1       2925000
# 603      0    3       16        13    24      45906137      1      36974064
# 604      0    3       16        17    37       5427000      1       1371000
#
# [605 rows x 8 columns]

# %%
mar_gap['gap'] =  (mar_gap['이용금액_y']/mar_gap['이용금액_x'])*3/5

# %%
mar_gap
# Out:
#      사용년_x  사용월  사용지역_도1  업종명_대분류1  업종명1        이용금액_x  사용년_y        이용금액_y  \
# 0        0    3        0         0     0  215161897702      1  147494192925
# 1        0    3        0         0     6   46294820641      1   33691383982
# 2        0    3        0         0     7   20570214952      1   18715095314
# 3        0    3        0         0     9   20476576751      1   13327780001
# 4        0    3        0         0    11   11259256477      1    7348439049
# ..     ...  ...      ...       ...   ...           ...    ...           ...
# 600      0    3       16        11    21      37542532      1      19025100
# 601      0    3       16        12    26      21802000      1      12071000
# 602      0    3       16        12    33       7038000      1       2925000
# 603      0    3       16        13    24      45906137      1      36974064
# 604      0    3       16        17    37       5427000      1       1371000
#
#           gap
# 0    0.411302
# 1    0.436654
# ...

# %%
mar_gap_1 = mar_gap[[
 '사용지역_도1',
 '업종명_대분류1',
 '업종명1',
 '이용금액_y',
 'gap']]

# %%
mar_gap_1.columns = [
 '사용지역_도1',
 '업종명_대분류1',
 '업종명1',
 'this_mar',
 'last_year_gap']
mar_gap_1
# Out:
#      사용지역_도1  업종명_대분류1  업종명1      this_mar  last_year_gap
# 0          0         0     0  147494192925       0.411302
# 1          0         0     6   33691383982       0.436654
# 2          0         0     7   18715095314       0.545889
# 3          0         0     9   13327780001       0.390528
# 4          0         0    11    7348439049       0.391595
# ..       ...       ...   ...           ...            ...
# 600       16        11    21      19025100       0.304057
# 601       16        12    26      12071000       0.332199
# 602       16        12    33       2925000       0.249361
# 603       16        13    24      36974064       0.483256
# 604       16        17    37       1371000       0.151575
#
# [605 rows x 5 columns]

# %%
submission
# Out:
#       사용년  사용월  사용지역_도1  업종명_대분류1  업종명1  이용금액
# 0       1    4        4         1    31     0
# 1       1    4        4         3    23     0
# 2       1    4        4         1    13     0
# 3       1    4        4         1    32     0
# 4       1    4        4        18    40     0
# ...   ...  ...      ...       ...   ...   ...
# 1389    1    7        8         0     7     0
# 1390    1    7        8         0     0     0
# 1391    1    7        8        14    27     0
# 1392    1    7        8         1    15     0
# 1393    1    7        8         3    30     0
#
# [1394 rows x 6 columns]

# %%
submission_1 = pd.merge(submission,mar_gap_1,how='left',on=['사용지역_도1','업종명_대분류1','업종명1'])
submission_1
# Out:
#       사용년  사용월  사용지역_도1  업종명_대분류1  업종명1  이용금액      this_mar  last_year_gap
# 0       1    4        4         1    31     0  9.605901e+07       0.526644
# 1       1    4        4         3    23     0  2.915798e+09       0.633755
# 2       1    4        4         1    13     0  9.948169e+08       0.635512
# 3       1    4        4         1    32     0  1.331730e+07       0.319319
# 4       1    4        4        18    40     0           NaN            NaN
# ...   ...  ...      ...       ...   ...   ...           ...            ...
# 1389    1    7        8         0     7     0  1.315245e+09       0.547588
# 1390    1    7        8         0     0     0  1.615248e+10       0.422241
# 1391    1    7        8        14    27     0  1.524855e+07       0.253931
# 1392    1    7        8         1    15     0  4.288814e+08       0.352830
# 1393    1    7        8         3    30     0  1.273349e+07       0.071116
#
# [1394 rows x 8 columns]

# %%
submission_2 = pd.merge(submission_1,last_april,how='left',on=['사용지역_도1','업종명_대분류1','업종명1'])
submission_2
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1  이용금액_x      this_mar  \
# 0         1      4        4         1    31       0  9.605901e+07
# 1         1      4        4         3    23       0  2.915798e+09
# 2         1      4        4         1    13       0  9.948169e+08
# 3         1      4        4         1    32       0  1.331730e+07
# 4         1      4        4        18    40       0           NaN
# ...     ...    ...      ...       ...   ...     ...           ...
# 1389      1      7        8         0     7       0  1.315245e+09
# 1390      1      7        8         0     0       0  1.615248e+10
# 1391      1      7        8        14    27       0  1.524855e+07
# 1392      1      7        8         1    15       0  4.288814e+08
# 1393      1      7        8         3    30       0  1.273349e+07
#
#       last_year_gap  사용년_y  사용월_y        이용금액_y
# 0          0.526644    0.0    4.0  1.065485e+08
# 1          0.633755    0.0    4.0  3.964893e+09
# ...

# %%
last_mar
# Out:
#       사용년  사용월  사용지역_도1  업종명_대분류1  업종명1          이용금액
# 1258    0    3        0         0     0  215161897702
# 1259    0    3        0         0     6   46294820641
# 1260    0    3        0         0     7   20570214952
# 1261    0    3        0         0     9   20476576751
# 1262    0    3        0         0    11   11259256477
# ...   ...  ...      ...       ...   ...           ...
# 1883    0    3       16        11    21      37542532
# 1884    0    3       16        12    26      21802000
# 1885    0    3       16        12    33       7038000
# 1886    0    3       16        13    24      45906137
# 1887    0    3       16        17    37       5427000
#
# [630 rows x 6 columns]

# %%
submission_2 = pd.merge(submission_1,last_april,how='left',on=['사용지역_도1','업종명_대분류1','업종명1'])
submission_2
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1  이용금액_x      this_mar  \
# 0         1      4        4         1    31       0  9.605901e+07
# 1         1      4        4         3    23       0  2.915798e+09
# 2         1      4        4         1    13       0  9.948169e+08
# 3         1      4        4         1    32       0  1.331730e+07
# 4         1      4        4        18    40       0           NaN
# ...     ...    ...      ...       ...   ...     ...           ...
# 1389      1      7        8         0     7       0  1.315245e+09
# 1390      1      7        8         0     0       0  1.615248e+10
# 1391      1      7        8        14    27       0  1.524855e+07
# 1392      1      7        8         1    15       0  4.288814e+08
# 1393      1      7        8         3    30       0  1.273349e+07
#
#       last_year_gap  사용년_y  사용월_y        이용금액_y
# 0          0.526644    0.0    4.0  1.065485e+08
# 1          0.633755    0.0    4.0  3.964893e+09
# ...

# %%
submission_2['이용금액_x'] = submission_2['이용금액_y']*submission_2['last_year_gap']

# %%
submission_2['이용금액_x'].isnull().sum()
# Out:
# 188

# %%
submission_3 = pd.merge(submission_2,last_mar,how='left',on=['사용지역_도1','업종명_대분류1','업종명1'])
submission_3
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1        이용금액_x      this_mar  \
# 0         1      4        4         1    31  5.611312e+07  9.605901e+07
# 1         1      4        4         3    23  2.512771e+09  2.915798e+09
# 2         1      4        4         1    13  5.260023e+08  9.948169e+08
# 3         1      4        4         1    32  5.717601e+06  1.331730e+07
# 4         1      4        4        18    40           NaN           NaN
# ...     ...    ...      ...       ...   ...           ...           ...
# 1389      1      7        8         0     7  7.821036e+08  1.315245e+09
# 1390      1      7        8         0     0  9.358084e+09  1.615248e+10
# 1391      1      7        8        14    27  1.028697e+07  1.524855e+07
# 1392      1      7        8         1    15  2.424839e+08  4.288814e+08
# 1393      1      7        8         3    30  7.248878e+06  1.273349e+07
#
#       last_year_gap  사용년_y  사용월_y        이용금액_y  사용년  사용월          이용금액
# ...

# %%
submission_4 = submission_3.iloc[:,:6]

# %%
submission_4[submission_4['업종명1']==40][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 400156.1964477989

# %%
submission_4[:50]
# Out:
#     사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1        이용금액_x
# 0       1      4        4         1    31  9.352186e+07
# 1       1      4        4         3    23  4.187951e+09
# 2       1      4        4         1    13  8.766705e+08
# 3       1      4        4         1    32  9.529336e+06
# 4       1      4        4        18    40           NaN
# 5       1      4        4         3    38  1.796936e+06
# 6       1      4        4         1    17  5.034736e+08
# 7       1      4        4         1     5  5.919117e+09
# 8       1      4        4        18    39  1.538236e+05
# 9       1      4        4         0    11  8.406421e+08
# 10      1      4        4        12    33  2.356987e+08
# 11      1      4        4         7    10  8.807792e+09
# 12      1      4        4         6    34  7.121942e+05
# 13      1      4        4        17    37  1.281740e+07
# 14      1      4        4        15    28           NaN
# 15      1      4        4         6    25           NaN
# ...

# %%
submission_4[submission_4['이용금액_x'].isnull()]
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1  이용금액_x
# 4         1      4        4        18    40     NaN
# 14        1      4        4        15    28     NaN
# 15        1      4        4         6    25     NaN
# 30        1      4        4         6    29     NaN
# 35        1      4        4         6    16     NaN
# ...     ...    ...      ...       ...   ...     ...
# 1367      1      7        8        15    28     NaN
# 1368      1      7        8         6    25     NaN
# 1376      1      7        8        16    35     NaN
# 1381      1      7        8         8    36     NaN
# 1383      1      7        8         6    29     NaN
#
# [188 rows x 6 columns]

# %%
submission_4[submission_4['이용금액_x'].isnull()].iloc[i,5]=0
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
submission_4.loc[4,'업종명1']
# Out:
# 40

# %%
submission_4[submission_4['업종명1']==submission_4.loc[4,'업종명1']][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 666926.9940796648

# %%
submission_4[submission_4['이용금액_x'].isnull()]
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1  이용금액_x
# 4         1      4        4        18    40     NaN
# 14        1      4        4        15    28     NaN
# 15        1      4        4         6    25     NaN
# 30        1      4        4         6    29     NaN
# 35        1      4        4         6    16     NaN
# ...     ...    ...      ...       ...   ...     ...
# 1367      1      7        8        15    28     NaN
# 1368      1      7        8         6    25     NaN
# 1376      1      7        8        16    35     NaN
# 1381      1      7        8         8    36     NaN
# 1383      1      7        8         6    29     NaN
#
# [188 rows x 6 columns]

# %%
submission_4[submission_4['이용금액_x'].isnull()].index
# Out:
# 4

# %%
submission_4.loc[4,'이용금액_x']
# Out:
# nan

# %%
submission_4[submission_4['업종명1']==40].loc[4,'이용금액_x'][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-0b828cf17461> in <module>
# ----> 1 submission_4[submission_4['업종명1']==40].loc[4,'이용금액_x'][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
#
# IndexError: invalid index to scalar variable.

# %%
submission_4[submission_4['업종명1']==submission_4[submission_4['이용금액_x'].isnull()].loc[4,'이용금액_x']][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# nan

# %%
for i in submission_4[submission_4['이용금액_x'].isnull()].index :
    
    submission_4.loc[i,'이용금액_x'] = submission_4[submission_4['업종명1']==submission_4.loc[i,'업종명1']][submission_4['이용금액_x'].notnull()]['이용금액_x'].mean()
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
submission_4
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1        이용금액_x
# 0         1      4        4         1    31  5.611312e+07
# 1         1      4        4         3    23  2.512771e+09
# 2         1      4        4         1    13  5.260023e+08
# 3         1      4        4         1    32  5.717601e+06
# 4         1      4        4        18    40  4.001562e+05
# ...     ...    ...      ...       ...   ...           ...
# 1389      1      7        8         0     7  7.821036e+08
# 1390      1      7        8         0     0  9.358084e+09
# 1391      1      7        8        14    27  1.028697e+07
# 1392      1      7        8         1    15  2.424839e+08
# 1393      1      7        8         3    30  7.248878e+06
#
# [1394 rows x 6 columns]

# %%
real_submission = pd.read_csv('submission1.csv')
real_submission['AMT'] = submission_4['이용금액_x']
real_submission.to_csv('submission_0702_3.csv', index=None, encoding='utf-8-sig')

# %%
submission_5 = submission_4.copy()

# %%
submission_5[submission_5['이용금액_x'].isnull()].iloc[i,5]=50
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
submission_5[submission_5['이용금액_x'].isnull()]
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1  이용금액_x
# 4         1      4        4        18    40     NaN
# 14        1      4        4        15    28     NaN
# 15        1      4        4         6    25     NaN
# 30        1      4        4         6    29     NaN
# 35        1      4        4         6    16     NaN
# ...     ...    ...      ...       ...   ...     ...
# 1367      1      7        8        15    28     NaN
# 1368      1      7        8         6    25     NaN
# 1376      1      7        8        16    35     NaN
# 1381      1      7        8         8    36     NaN
# 1383      1      7        8         6    29     NaN
#
# [188 rows x 6 columns]

# %%
submission_4[submission_4['이용금액_x'].isnull()].iloc[0,4]
# Out:
# 40

# %%
submission_4[submission_4['이용금액_x'].isnull()].iloc[1,5] =
# Out:
#   File "<ipython-input-90-39f1c5805e46>", line 1
#     submission_4[submission_4['이용금액_x'].isnull()].iloc[1,5] =
#                                                               ^
# SyntaxError: invalid syntax

# %%
submission_3[submission_3['이용금액_x']==None]
# Out:
# Empty DataFrame
# Columns: [사용년_x, 사용월_x, 사용지역_도1, 업종명_대분류1, 업종명1, 이용금액_x, this_mar, last_year_gap, 사용년_y, 사용월_y, 이용금액_y, 사용년, 사용월, 이용금액, 이용금액_may]
# Index: []

# %%
submission_3['이용금액_may'] = submission_3['이용금액']*submission_3['last_year_gap']

# %%
submission_3[['이용금액_x','이용금액_may']][-50:]
# Out:
#             이용금액_x      이용금액_may
# 1344  7.817858e+08  8.628667e+08
# 1345  2.863804e+10  2.924342e+10
# 1346  1.303756e+10  1.292348e+10
# 1347           NaN           NaN
# 1348  1.940645e+09  1.961622e+09
# 1349  2.109348e+10  2.165835e+10
# 1350  4.215949e+06  8.423086e+06
# 1351  8.687518e+08  9.381569e+08
# 1352  4.679283e+07  4.077782e+07
# 1353  1.007790e+08  1.089949e+08
# 1354  3.347195e+09  2.520056e+09
# 1355  8.119712e+08  7.780146e+08
# 1356  1.633876e+07  2.203097e+07
# 1357           NaN           NaN
# 1358  1.493154e+06  1.542000e+06
# 1359  2.036828e+09  2.018012e+09
# 1360  7.340158e+09  7.340310e+09
# 1361  7.380777e+05  9.420000e+05
# 1362  8.622451e+08  8.979285e+08
# 1363  1.261215e+08  1.335603e+08
# 1364  3.653968e+09  3.568038e+09
# 1365           NaN           NaN
# 1366  4.886470e+06  5.711000e+06
# 1367           NaN           NaN
# 1368           NaN           NaN
# 1369  8.023135e+08  7.910442e+08
# 1370  1.273399e+09  1.349318e+09
# ...

# %%
submission_2[:50]
# Out:
#     사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1        이용금액_x      this_mar  \
# 0       1      4        4         1    31  9.352186e+07  9.605901e+07
# 1       1      4        4         3    23  4.187951e+09  2.915798e+09
# 2       1      4        4         1    13  8.766705e+08  9.948169e+08
# 3       1      4        4         1    32  9.529336e+06  1.331730e+07
# 4       1      4        4        18    40           NaN           NaN
# 5       1      4        4         3    38  1.796936e+06  2.075000e+06
# 6       1      4        4         1    17  5.034736e+08  4.702002e+08
# 7       1      4        4         1     5  5.919117e+09  6.384111e+09
# 8       1      4        4        18    39  1.538236e+05  2.610000e+05
# 9       1      4        4         0    11  8.406421e+08  8.876362e+08
# 10      1      4        4        12    33  2.356987e+08  2.507374e+08
# 11      1      4        4         7    10  8.807792e+09  8.543165e+09
# ...

# %%
submission_2.fillna(submission_2.mean())
# Out:
#       사용년_x  사용월_x  사용지역_도1  업종명_대분류1  업종명1        이용금액_x      this_mar  \
# 0         1      4        4         1    31  9.316846e+07  9.605901e+07
# 1         1      4        4         3    23  4.120194e+09  2.915798e+09
# 2         1      4        4         1    13  8.832724e+08  9.948169e+08
# 3         1      4        4         1    32  6.199720e+06  1.331730e+07
# 4         1      4        4        18    40  5.537663e+09  5.682449e+09
# ...     ...    ...      ...       ...   ...           ...           ...
# 1389      1      7        8         0     7  1.302382e+09  1.315245e+09
# 1390      1      7        8         0     0  1.536287e+10  1.615248e+10
# 1391      1      7        8        14    27  1.972947e+07  1.524855e+07
# 1392      1      7        8         1    15  3.868074e+08  4.288814e+08
# 1393      1      7        8         3    30  7.232397e+06  1.273349e+07
#
#       last_year_gap  사용년_y  사용월_y        이용금액_y
# 0     -1.338001e+07    0.0    4.0  1.065485e+08
# ...

# %%
real_submission
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  9.316846e+07
# 1        1    202004           강원                골프장 운영업  4.120194e+09
# 2        2    202004           강원            과실 및 채소 소매업  8.832724e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  6.199720e+06
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업           NaN
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.302382e+09
# 1390  1390    202007           충북                한식 음식점업  1.536287e+10
# 1391  1391    202007           충북                    호텔업  1.972947e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  3.868074e+08
# 1393  1393    202007           충북               휴양콘도 운영업  7.232397e+06
#
# [1394 rows x 5 columns]

# %%
real_submission = pd.read_csv('submission1.csv')
real_submission['AMT'] = submission_2['이용금액_x']
real_submission.to_csv('submission_0701_2.csv', index=None, encoding='utf-8-sig')

# %%
list(submission_2)
# Out:
# ['사용년_x',
#  '사용월_x',
#  '사용지역_도1',
#  '업종명_대분류1',
#  '업종명1',
#  '이용금액_x',
#  'this_mar',
#  'last_year_gap',
#  '사용년_y',
#  '사용월_y',
#  '이용금액_y']

# %%
submission_3 = submission_2[['사용년_x',
 '사용월_x',
 '사용지역_도1',
 '업종명_대분류1',
 '업종명1',
 '이용금액_x',
 'this_mar',
 'last_year_gap',
 '사용년_y',
 '사용월_y',
 '이용금액_y']]

# %%
this_mar[this_mar['사용지역_도1']==0][this_mar['업종명_대분류1']==1]
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       사용년  사용월  사용지역_도1  업종명_대분류1  업종명1         이용금액
# 8835    1    3        0         1     5  85944403598
# 8836    1    3        0         1     8  14350083255
# 8837    1    3        0         1    13   8005379734
# 8838    1    3        0         1    15  15531843111
# 8839    1    3        0         1    17  40433017255
# 8840    1    3        0         1    20  16014475439
# 8841    1    3        0         1    22   3342043120
# 8842    1    3        0         1    31   1178972099
# 8843    1    3        0         1    32     53586140

# %%
this_mar=dataset[dataset['사용년']==1][dataset['사용월']==3]
this_mar
# Out:
# C:\Users\bitcamp\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       사용년  사용월  사용지역_도1  업종명_대분류1  업종명1          이용금액
# 8829    1    3        0         0     0  147494192925
# 8830    1    3        0         0     6   33691383982
# 8831    1    3        0         0     7   18715095314
# 8832    1    3        0         0     9   13327780001
# 8833    1    3        0         0    11    7348439049
# ...   ...  ...      ...       ...   ...           ...
# 9433    1    3       16        11    21      19025100
# 9434    1    3       16        12    26      12071000
# 9435    1    3       16        12    33       2925000
# 9436    1    3       16        13    24      36974064
# 9437    1    3       16        17    37       1371000
#
# [609 rows x 6 columns]

# %%
x = this_mar.iloc[:,2:5]
y = this_mar.iloc[:,5]

# %%
y
# Out:
# 8829    147494192925
# 8830     33691383982
# 8831     18715095314
# 8832     13327780001
# 8833      7348439049
#             ...
# 9433        19025100
# 9434        12071000
# 9435         2925000
# 9436        36974064
# 9437         1371000
# Name: 이용금액, Length: 609, dtype: int64

# %%
test = submission.iloc[:,2:5]

# %% [markdown]
# # 머신러닝

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline , make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV, RandomizedSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, random_state=66, test_size=0.2)

# %%
pipe = Pipeline([("scaler",RobustScaler()),('rf',RandomForestRegressor())])

# %%
parameters = [
    { 'rf__max_depth':[3,5,25,100, 200, 300],
     'rf__n_estimators':[10, 50, 150, 250, 300],
    'rf__max_leaf_nodes':[1000000,1005000,10000000]}
]

# %%
model = RandomizedSearchCV(pipe, parameters, cv=5)
model.fit(x_train, y_train)
pred = model.predict(x_test)
RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
MAE = mean_absolute_error(y_test, pred)
print('rmsle는',RMSLE)
print('mae는',MAE)
# Out:
# rmsle는 1.8252680311200438
# mae는 3134233348.3034973

# %%
test_pred = model.predict(test)
real_submission = pd.read_csv('submission1.csv')
real_submission['AMT'] = test_pred
real_submission.to_csv('submission_0701_1.csv', index=None, encoding='utf-8-sig')

# %%
print("============================")
print("최적의 매개 변수는(estimator):", model.best_estimator_) # 전체 params 다 나옴
print("============================")
print("최적의 매개 변수는(params):", model.best_params_)
print("============================")
# Out:
# ...
# 최적의 매개 변수는(estimator): Pipeline(memory=None,
#          steps=[('scaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               with_centering=True, with_scaling=True)),
#                 ('rf',
#                  RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                        criterion='mse', max_depth=100,
#                                        max_features='auto',
#                                        max_leaf_nodes=1005000, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=300, n_jobs=None,
#                                        oob_score=False, random_state=None,
# ...

# %%
model = RandomForestRegressor(n_estimators=300)
model.fit(x_train, y_train)
pred = model.predict(x_test)
RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
RMSLE
# Out:
# 1.8484167144181893

# %%
model = RandomForestRegressor(n_estimators=150)
model.fit(x_train, y_train)
pred = model.predict(x_test)
RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
MAE = mean_absolute_error(y_test, pred)
print('rmsle는',RMSLE)
print('mae는',MAE)
# Out:
# rmsle는 1.8522503186899872
# mae는 3211696601.852732

# %%
model = XGBRegressor(n_estimators=150)
model.fit(x_train, y_train)
pred = model.predict(x_test)
RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
MAE = mean_absolute_error(y_test, pred)
print('rmsle는',RMSLE)
print('mae는',MAE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-6135ed00ca51> in <module>
#       2 model.fit(x_train, y_train)
#       3 pred = model.predict(x_test)
# ----> 4 RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
#       5 MAE = mean_absolute_error(y_test, pred)
#       6 print('rmsle는',RMSLE)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_log_error(y_true, y_pred, sample_weight, multioutput)
#     324
#     325     if (y_true < 0).any() or (y_pred < 0).any():
# --> 326         raise ValueError("Mean Squared Logarithmic Error cannot be used when "
#     327                          "targets contain negative values.")
#     328
#
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.

# %%
test_pred = model.predict(test)
real_submission = pd.read_csv('submission1.csv')
real_submission['AMT'] = test_pred
real_submission.to_csv('submission_0630_2.csv', index=None, encoding='utf-8-sig')

# %%
submission_real
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  9.751899e+07
# 1        1    202004           강원                골프장 운영업  3.760515e+09
# 2        2    202004           강원            과실 및 채소 소매업  9.334674e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  1.834808e+07
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업  1.619220e+06
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.462200e+09
# 1390  1390    202007           충북                한식 음식점업  2.084806e+10
# 1391  1391    202007           충북                    호텔업  1.708192e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  4.778178e+08
# 1393  1393    202007           충북               휴양콘도 운영업  2.197401e+08
#
# [1394 rows x 5 columns]

# %%
submission_real.to_csv('submission_0630_1.csv', index=None, encoding='utf-8-sig')

# %%
submission_real
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  9.751899e+07
# 1        1    202004           강원                골프장 운영업  3.760515e+09
# 2        2    202004           강원            과실 및 채소 소매업  9.334674e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  1.834808e+07
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업  1.619220e+06
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  1.462200e+09
# 1390  1390    202007           충북                한식 음식점업  2.084806e+10
# 1391  1391    202007           충북                    호텔업  1.708192e+07
# 1392  1392    202007           충북          화장품 및 방향제 소매업  4.778178e+08
# 1393  1393    202007           충북               휴양콘도 운영업  2.197401e+08
#
# [1394 rows x 5 columns]

# %%
submission_real = submission_real.reset_index()

# %%
submission_real.to_csv('submission_0630_1.csv', index=None, encoding='utf-8-sig')

# %%
# xgb 완전 쓰레기...

# %%
x_train.shape
# Out:
# (7550, 5)

# %%
x_test.shape
# Out:
# (1888, 5)

# %%
from keras.models import Sequential, Model 
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LSTM

model = Sequential()
model.add(Dense(1600, input_shape=(3,), activation='elu'))
model.add(Dense(3600, activation='elu'))
model.add(Dropout(0.2))

model.add(Dense(1280, activation='elu'))
model.add(Dense(640, activation='elu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='elu'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 1600)              6400
# _________________________________________________________________
# dense_7 (Dense)              (None, 3600)              5763600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3600)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1280)              4609280
# _________________________________________________________________
# dense_9 (Dense)              (None, 640)               819840
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 640)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 641
# ...

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])
model.fit(x_train, y_train, epochs=500, batch_size=100, validation_split=0.2)
# Out:
# Train on 389 samples, validate on 98 samples
# Epoch 1/500
# 389/389 [==============================] - 1s 2ms/step - loss: 246692097290556473344.0000 - mse: 246692093491729661952.0000 - val_loss: 358196400006446972928.0000 - val_mse: 358196400006446972928.0000
# Epoch 2/500
# 389/389 [==============================] - 0s 97us/step - loss: 246692102717451927552.0000 - mse: 246692093491729661952.0000 - val_loss: 358196400006446972928.0000 - val_mse: 358196400006446972928.0000
# Epoch 3/500
# 389/389 [==============================] - 0s 95us/step - loss: 246692032846173143040.0000 - mse: 246692040715171528704.0000 - val_loss: 358196329637702795264.0000 - val_mse: 358196329637702795264.0000
# Epoch 4/500
# 389/389 [==============================] - 0s 92us/step - loss: 246691894188994723840.0000 - mse: 246691882385497128960.0000 - val_loss: 358196118531470262272.0000 - val_mse: 358196118531470262272.0000
# Epoch 5/500
# ...

# %%
pred = model.predict(x_test)
RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
MAE = mean_absolute_error(y_test, pred)
print('rmsle는',RMSLE)
print('mae는',MAE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-58222f486d26> in <module>
#       1 pred = model.predict(x_test)
# ----> 2 RMSLE = np.sqrt(mean_squared_log_error(y_test, pred))
#       3 MAE = mean_absolute_error(y_test, pred)
#       4 print('rmsle는',RMSLE)
#       5 print('mae는',MAE)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_log_error(y_true, y_pred, sample_weight, multioutput)
#     324
#     325     if (y_true < 0).any() or (y_pred < 0).any():
# --> 326         raise ValueError("Mean Squared Logarithmic Error cannot be used when "
#     327                          "targets contain negative values.")
#     328
#
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.

# %%
x_train = x_train.reshape(7550,5,1)
x_test = x_test.reshape(1888,5,1)

# %%
from keras.models import Sequential, Model 
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, LSTM

model = Sequential()
model.add(LSTM(160, input_shape=(5,)))
model.add(Dense(160))
model.add(Dropout(0.2))

model.add(Dense(128))
model.add(Dense(64))
model.add(Dropout(0.2))

model.add(Dense(1, activation='relu'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 16)                96
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                1088
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# ...

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])
model.fit(x_train, y_train, epochs=50, batch_size=2, validation_split=0.2)
# Out:
# Train on 6040 samples, validate on 1510 samples
# Epoch 1/50
# 6040/6040 [==============================] - 9s 1ms/step - loss: 389524191217854513152.0000 - mse: 389523966780017475584.0000 - val_loss: 385864514416192389120.0000 - val_mse: 385864651345290592256.0000
# Epoch 2/50
# 6040/6040 [==============================] - 9s 1ms/step - loss: 385136523063873503232.0000 - mse: 385136299658679681024.0000 - val_loss: 380919034811891974144.0000 - val_mse: 380918924898251833344.0000
# Epoch 3/50
# 6040/6040 [==============================] - 9s 1ms/step - loss: 377712754277390483456.0000 - mse: 377712608254168662016.0000 - val_loss: 371906013596131655680.0000 - val_mse: 371906096143976628224.0000
# Epoch 4/50
# 6040/6040 [==============================] - 9s 1ms/step - loss: 364756766988976455680.0000 - mse: 364756174338688811008.0000 - val_loss: 359675310217679077376.0000 - val_mse: 359675445455945203712.0000
# Epoch 5/50
# ...
