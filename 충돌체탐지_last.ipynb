# %%
import os
import json
import numpy as np
from tqdm import tqdm
# import jovian
import numpy as np

def kaeri_metric(y_true, y_pred):
    '''
    y_true: dataframe with true values of X,Y,M,V
    y_pred: dataframe with pred values of X,Y,M,V
    
    return: KAERI metric
    '''
    
    return 0.5 * E1(y_true, y_pred) + 0.5 * E2(y_true, y_pred)


### E1과 E2는 아래에 정의됨 ###

def E1(y_true, y_pred):
    '''
    y_true: dataframe with true values of X,Y,M,V
    y_pred: dataframe with pred values of X,Y,M,V
    
    return: distance error normalized with 2e+04
    '''
    
    _t, _p = np.array(y_true)[:,:2], np.array(y_pred)[:,:2]
    
    return np.mean(np.sum(np.square(_t - _p), axis = 1) / 2e+04)


def E2(y_true, y_pred):
    '''
    y_true: dataframe with true values of X,Y,M,V
    y_pred: dataframe with pred values of X,Y,M,V
    
    return: sum of mass and velocity's mean squared percentage error
    '''
    
    _t, _p = np.array(y_true)[:,2:], np.array(y_pred)[:,2:]
    
    
    return np.mean(np.sum(np.square((_t - _p) / (_t + 1e-06)), axis = 1))

# import matplotlib as plt
import matplotlib.pyplot as plt

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, Flatten,MaxPooling2D,BatchNormalization,Lambda, AveragePooling2D
import keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import pandas as pd
from sklearn.model_selection import train_test_split

# X_data = []
# Y_data = []

X_data = np.loadtxt('train_features.csv',skiprows=1,delimiter=',')
X_data = X_data[:,1:]
print(X_data.shape)
     
    
Y_data = np.loadtxt('train_target.csv',skiprows=1,delimiter=',')
Y_data = Y_data[:,1:]
print(Y_data.shape)

X_data = X_data.reshape((2800,375,5,1))
print(X_data.shape)

X_data_test = np.loadtxt('test_features.csv',skiprows=1,delimiter=',')
X_data_test = X_data_test[:,1:]
X_data_test = X_data_test.reshape((700,375,5,1))

data_id = 2

plt.figure(figsize=(8,6))


plt.plot(X_data[data_id,:,0,0], label="Sensor #1")
plt.plot(X_data[data_id,:,1,0], label="Sensor #2")
plt.plot(X_data[data_id,:,2,0], label="Sensor #3")
plt.plot(X_data[data_id,:,3,0], label="Sensor #4")

plt.xlabel("Time", labelpad=10, size=20)
plt.ylabel("Acceleration", labelpad=10, size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.xlim(0, 400)
plt.legend(loc=1)

# plt.show()

from sklearn.model_selection import train_test_split


X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2)
# X_train = X_data
# Y_train = Y_data
print(X_train.shape)

weight1 = np.array([1,1,0,0])
weight2 = np.array([0,0,1,1])

def my_loss(y_true, y_pred):
    divResult = Lambda(lambda x: x[0]/x[1])([(y_pred-y_true),(y_true+0.000001)])
    return K.mean(K.square(divResult))


def my_loss_E1(y_true, y_pred):
    return K.mean(K.square(y_true-y_pred)*weight1)/2e+04

def my_loss_E2(y_true, y_pred):
    divResult = Lambda(lambda x: x[0]/x[1])([(y_pred-y_true),(y_true+0.000001)])
    return K.mean(K.square(divResult)*weight2)

# tr_target = 2 

def set_model(train_target):  # 0:x,y, 1:m, 2:v
    
    activation = 'selu'
    padding = 'valid'
    model = Sequential()
    nf = 19
    fs = (3,1)

    model.add(Conv2D(nf,fs, padding=padding, activation=activation,input_shape=(375,5,1)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Conv2D(nf*2,fs, padding=padding, activation=activation))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Conv2D(nf*4,fs, padding=padding, activation=activation))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Conv2D(nf*8,fs, padding=padding, activation=activation))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Conv2D(nf*16,fs, padding=padding, activation=activation))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Conv2D(nf*32,fs, padding=padding, activation=activation))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 1)))

    model.add(Flatten())
    model.add(Dense(128, activation ='selu'))
    model.add(Dense(64, activation ='selu'))
    model.add(Dense(84, activation ='selu'))
    model.add(Dense(32, activation ='selu'))
    model.add(Dense(16, activation ='selu'))
    model.add(Dense(4))

    optimizer = keras.optimizers.Adam()

    global weight2
    if train_target == 1: # only for M
        weight2 = np.array([0,0,1,0])
    else: # only for V
        weight2 = np.array([0,0,0,1])
       
    if train_target==0:
        model.compile(loss=my_loss_E1,
                  optimizer=optimizer,
                 )
    else:
        model.compile(loss=my_loss_E2,
                  optimizer=optimizer,
                 )
       
    model.summary()

    return model

def train(model,X,Y):
    MODEL_SAVE_FOLDER_PATH = './model/'
    if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
        os.mkdir(MODEL_SAVE_FOLDER_PATH)

    model_path = MODEL_SAVE_FOLDER_PATH + '{epoch:02d}-{val_loss:.4f}.hdf5'
    best_save = ModelCheckpoint('best_m.hdf5', save_best_only=True, monitor='val_loss', mode='min')


    history = model.fit(X, Y,
                  epochs=300,
                  batch_size=220,
                  shuffle=True,
                  validation_split=0.2,
                  verbose = 2,
                  callbacks=[best_save])

    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()

    loss_ax.plot(history.history['loss'], 'y', label='train loss')
    loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    loss_ax.legend(loc='upper left')
    # plt.show()    
    
    return model

def plot_error(type_id,pred,true):
    print(pred.shape)

    if type_id == 0:
        _name = 'x_pos'
    elif type_id == 1:
        _name = 'y_pos'
    elif type_id == 2:
        _name = 'mass'
    elif type_id == 3:
        _name = 'velocity'
    elif type_id == 4:
        _name = "distance"
    else:
        _name = 'error'

    x_coord = np.arange(1,pred.shape[0]+1,1)
    if type_id < 2:
        Err_m = (pred[:,type_id] - true[:,type_id])
    elif type_id < 4:
        Err_m = ((pred[:,type_id] - true[:,type_id])/true[:,type_id])*100
    else:
        Err_m = ((pred[:,0]-true[:,0])**2+(pred[:,1]-true[:,1])**2)**0.5


    fig = plt.figure(figsize=(8,6))
    # plt.rcParams["font.family"]="Times New Roman"
    plt.rcParams["font.size"]=15
    plt.scatter(x_coord, Err_m, marker='o')
    plt.title("%s Prediction for Training Data" % _name, size=20)
    plt.xlabel("Data ID", labelpad=10, size=20)
    plt.ylabel("Prediction Error of %s," % _name, labelpad=10, size=20)
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.ylim(-100., 100.)
    plt.xlim(0, pred.shape[0]+1)

    # plt.show()
    
    print(np.std(Err_m))
    print(np.max(Err_m))
    print(np.min(Err_m))
    return Err_m

#  plot_error(type_id,pred,true):

def load_best_model(train_target):
    
    if train_target == 0:
        model = load_model('best_m.hdf5' , custom_objects={'my_loss_E1': my_loss, })
    else:
        model = load_model('best_m.hdf5' , custom_objects={'my_loss_E2': my_loss, })

    score = model.evaluate(X_data, Y_data, verbose=0)
    print('loss:', score)

    pred = model.predict(X_data)

    i=0

    print('정답(original):', Y_data[i])
    print('예측값(original):', pred[i])

    print(E1(pred, Y_data))
    print(E2(pred, Y_data))
    # print(E2M(pred, Y_data))
    # print(E2V(pred, Y_data))    
    
    if train_target ==0:
        plot_error(4,pred,Y_data)
    elif train_target ==1:
        plot_error(2,pred,Y_data)
    elif train_target ==2:
        plot_error(3,pred,Y_data)    
    
    return model

submit = pd.read_csv('sample_submission.csv')

for train_target in range(3):
    model = set_model(train_target)
    train(model,X_train, Y_train)    
    best_model = load_best_model(train_target)

   
    pred_data_test = best_model.predict(X_data_test)
    
    
    if train_target == 0: # x,y 학습
        submit.iloc[:,1] = pred_data_test[:,0]
        submit.iloc[:,2] = pred_data_test[:,1]

    elif train_target == 1: # m 학습
        submit.iloc[:,3] = pred_data_test[:,2]

    elif train_target == 2: # v 학습
        submit.iloc[:,4] = pred_data_test[:,3]

submit.to_csv('0710_3.csv', index = False)
# Out:
# (1050000, 5)
# (2800, 4)
# (2800, 375, 5, 1)
# (2240, 375, 5, 1)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 373, 5, 19)        76
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 373, 5, 19)        76
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 186, 5, 19)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 184, 5, 38)        2204
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 184, 5, 38)        152
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 92, 5, 38)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 90, 5, 76)         8740
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 90, 5, 76)         304
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 45, 5, 76)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 43, 5, 152)        34808
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 43, 5, 152)        608
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 21, 5, 152)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 19, 5, 304)        138928
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 19, 5, 304)        1216
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 9, 5, 304)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 7, 5, 608)         555104
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 7, 5, 608)         2432
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 3, 5, 608)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 9120)              0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               1167488
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_39 (Dense)             (None, 84)                5460
# _________________________________________________________________
# dense_40 (Dense)             (None, 32)                2720
# _________________________________________________________________
# dense_41 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_42 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 1,929,168
# Trainable params: 1,926,774
# Non-trainable params: 2,394
# _________________________________________________________________
# Train on 1792 samples, validate on 448 samples
# Epoch 1/300
#  - 2s - loss: 1.4661 - val_loss: 0.9176
# Epoch 2/300
#  - 1s - loss: 0.6478 - val_loss: 0.4805
# Epoch 3/300
#  - 1s - loss: 0.1277 - val_loss: 0.1831
# Epoch 4/300
#  - 1s - loss: 0.0497 - val_loss: 0.2915
# Epoch 5/300
#  - 1s - loss: 0.0256 - val_loss: 0.2401
# Epoch 6/300
#  - 1s - loss: 0.0130 - val_loss: 0.2204
# Epoch 7/300
#  - 1s - loss: 0.0074 - val_loss: 0.3243
# Epoch 8/300
#  - 1s - loss: 0.0038 - val_loss: 0.3523
# Epoch 9/300
#  - 1s - loss: 0.0024 - val_loss: 0.3365
# Epoch 10/300
#  - 1s - loss: 0.0020 - val_loss: 0.3085
# Epoch 11/300
#  - 1s - loss: 0.0017 - val_loss: 0.3291
# Epoch 12/300
#  - 1s - loss: 0.0019 - val_loss: 0.2866
# Epoch 13/300
#  - 1s - loss: 0.0013 - val_loss: 0.3108
# Epoch 14/300
#  - 1s - loss: 0.0010 - val_loss: 0.3060
# Epoch 15/300
#  - 1s - loss: 0.0010 - val_loss: 0.2459
# Epoch 16/300
#  - 1s - loss: 0.0014 - val_loss: 0.2671
# Epoch 17/300
#  - 1s - loss: 0.0013 - val_loss: 0.2200
# Epoch 18/300
#  - 1s - loss: 8.8983e-04 - val_loss: 0.1948
# Epoch 19/300
#  - 1s - loss: 9.9047e-04 - val_loss: 0.1524
# Epoch 20/300
#  - 1s - loss: 0.0022 - val_loss: 0.1162
# Epoch 21/300
#  - 1s - loss: 7.7715e-04 - val_loss: 0.1198
# Epoch 22/300
#  - 1s - loss: 0.0011 - val_loss: 0.1139
# Epoch 23/300
#  - 1s - loss: 0.0013 - val_loss: 0.0958
# Epoch 24/300
#  - 1s - loss: 0.0011 - val_loss: 0.0975
# Epoch 25/300
#  - 1s - loss: 0.0019 - val_loss: 0.0646
# Epoch 26/300
#  - 1s - loss: 9.6664e-04 - val_loss: 0.0202
# Epoch 27/300
#  - 1s - loss: 0.0026 - val_loss: 0.0327
# Epoch 28/300
#  - 1s - loss: 0.0015 - val_loss: 0.0220
# Epoch 29/300
#  - 1s - loss: 0.0013 - val_loss: 0.0319
# Epoch 30/300
#  - 1s - loss: 0.0010 - val_loss: 0.0289
# Epoch 31/300
#  - 1s - loss: 7.5294e-04 - val_loss: 0.0186
# Epoch 32/300
#  - 1s - loss: 5.8831e-04 - val_loss: 0.0025
# Epoch 33/300
#  - 1s - loss: 5.6959e-04 - val_loss: 0.0080
# Epoch 34/300
#  - 1s - loss: 0.0036 - val_loss: 0.0183
# Epoch 35/300
#  - 1s - loss: 0.0025 - val_loss: 0.0021
# Epoch 36/300
#  - 1s - loss: 0.0015 - val_loss: 0.0120
# Epoch 37/300
#  - 1s - loss: 9.9173e-04 - val_loss: 0.0014
# Epoch 38/300
#  - 1s - loss: 6.7647e-04 - val_loss: 0.0024
# Epoch 39/300
#  - 1s - loss: 0.0014 - val_loss: 0.0038
# Epoch 40/300
#  - 1s - loss: 6.6806e-04 - val_loss: 0.0046
# Epoch 41/300
#  - 1s - loss: 5.8589e-04 - val_loss: 0.0032
# Epoch 42/300
#  - 1s - loss: 0.0018 - val_loss: 0.0028
# Epoch 43/300
#  - 1s - loss: 0.0016 - val_loss: 0.0023
# Epoch 44/300
#  - 1s - loss: 0.0012 - val_loss: 0.0096
# Epoch 45/300
#  - 1s - loss: 0.0011 - val_loss: 0.0045
# Epoch 46/300
#  - 1s - loss: 5.5621e-04 - val_loss: 0.0030
# Epoch 47/300
#  - 1s - loss: 4.0175e-04 - val_loss: 8.5166e-04
# Epoch 48/300
#  - 1s - loss: 2.8963e-04 - val_loss: 6.0961e-04
# Epoch 49/300
#  - 1s - loss: 5.6564e-04 - val_loss: 0.0011
# Epoch 50/300
#  - 1s - loss: 0.0012 - val_loss: 0.0016
# Epoch 51/300
#  - 1s - loss: 7.4961e-04 - val_loss: 0.0010
# Epoch 52/300
#  - 1s - loss: 0.0010 - val_loss: 0.0021
# Epoch 53/300
#  - 1s - loss: 7.3411e-04 - val_loss: 0.0012
# Epoch 54/300
#  - 1s - loss: 0.0014 - val_loss: 0.0028
# Epoch 55/300
#  - 1s - loss: 0.0017 - val_loss: 0.0092
# Epoch 56/300
#  - 1s - loss: 0.0012 - val_loss: 0.0046
# Epoch 57/300
#  - 1s - loss: 8.7927e-04 - val_loss: 9.6999e-04
# Epoch 58/300
#  - 1s - loss: 6.5966e-04 - val_loss: 0.0043
# Epoch 59/300
#  - 1s - loss: 0.0011 - val_loss: 9.7173e-04
# Epoch 60/300
#  - 1s - loss: 0.0011 - val_loss: 0.0173
# Epoch 61/300
#  - 1s - loss: 0.0015 - val_loss: 0.0275
# Epoch 62/300
#  - 1s - loss: 7.2527e-04 - val_loss: 0.0072
# Epoch 63/300
#  - 1s - loss: 6.0642e-04 - val_loss: 0.0013
# Epoch 64/300
#  - 1s - loss: 5.4475e-04 - val_loss: 0.0029
# Epoch 65/300
#  - 1s - loss: 3.5426e-04 - val_loss: 0.0192
# Epoch 66/300
#  - 1s - loss: 3.2303e-04 - val_loss: 0.0054
# Epoch 67/300
#  - 1s - loss: 4.6073e-04 - val_loss: 0.0017
# Epoch 68/300
#  - 1s - loss: 0.0013 - val_loss: 0.0030
# Epoch 69/300
#  - 1s - loss: 0.0014 - val_loss: 0.0022
# Epoch 70/300
#  - 1s - loss: 5.4912e-04 - val_loss: 0.0196
# Epoch 71/300
#  - 1s - loss: 5.1995e-04 - val_loss: 0.0072
# Epoch 72/300
#  - 1s - loss: 7.9992e-04 - val_loss: 0.0163
# Epoch 73/300
#  - 1s - loss: 6.2780e-04 - val_loss: 0.0074
# Epoch 74/300
#  - 1s - loss: 5.8379e-04 - val_loss: 0.0119
# Epoch 75/300
#  - 1s - loss: 7.5279e-04 - val_loss: 0.0198
# Epoch 76/300
#  - 1s - loss: 2.8148e-04 - val_loss: 0.0033
# Epoch 77/300
#  - 1s - loss: 5.4508e-04 - val_loss: 3.2231e-04
# Epoch 78/300
#  - 1s - loss: 4.5124e-04 - val_loss: 0.0153
# Epoch 79/300
#  - 1s - loss: 3.6380e-04 - val_loss: 0.0070
# Epoch 80/300
#  - 1s - loss: 2.9802e-04 - val_loss: 0.0013
# Epoch 81/300
#  - 1s - loss: 1.6153e-04 - val_loss: 0.0047
# Epoch 82/300
#  - 1s - loss: 5.1036e-04 - val_loss: 5.5076e-04
# Epoch 83/300
#  - 1s - loss: 2.5908e-04 - val_loss: 6.1798e-04
# Epoch 84/300
#  - 1s - loss: 8.1842e-04 - val_loss: 0.0014
# Epoch 85/300
#  - 1s - loss: 6.8841e-04 - val_loss: 0.0025
# Epoch 86/300
#  - 1s - loss: 0.0011 - val_loss: 0.0059
# Epoch 87/300
#  - 1s - loss: 0.0010 - val_loss: 0.0019
# Epoch 88/300
#  - 1s - loss: 9.6484e-04 - val_loss: 8.3084e-04
# Epoch 89/300
#  - 1s - loss: 7.3072e-04 - val_loss: 0.0062
# Epoch 90/300
#  - 1s - loss: 2.6541e-04 - val_loss: 0.0095
# Epoch 91/300
#  - 1s - loss: 2.1575e-04 - val_loss: 0.0025
# Epoch 92/300
#  - 1s - loss: 2.9584e-04 - val_loss: 0.0019
# Epoch 93/300
#  - 1s - loss: 4.4112e-04 - val_loss: 0.0024
# Epoch 94/300
#  - 1s - loss: 0.0013 - val_loss: 0.0015
# Epoch 95/300
#  - 1s - loss: 0.0013 - val_loss: 0.0131
# Epoch 96/300
#  - 1s - loss: 0.0023 - val_loss: 0.0106
# Epoch 97/300
#  - 1s - loss: 7.3125e-04 - val_loss: 0.0026
# Epoch 98/300
#  - 1s - loss: 4.7913e-04 - val_loss: 0.0081
# Epoch 99/300
#  - 1s - loss: 4.4659e-04 - val_loss: 0.0034
# Epoch 100/300
#  - 1s - loss: 7.4791e-04 - val_loss: 0.0061
# Epoch 101/300
#  - 1s - loss: 8.8268e-04 - val_loss: 0.0018
# Epoch 102/300
#  - 1s - loss: 6.6016e-04 - val_loss: 0.0016
# Epoch 103/300
#  - 1s - loss: 5.1747e-04 - val_loss: 0.0018
# Epoch 104/300
#  - 1s - loss: 6.2129e-04 - val_loss: 0.0065
# Epoch 105/300
#  - 1s - loss: 8.7451e-04 - val_loss: 0.0027
# Epoch 106/300
#  - 1s - loss: 7.3253e-04 - val_loss: 0.0091
# Epoch 107/300
#  - 1s - loss: 8.0191e-04 - val_loss: 0.0034
# Epoch 108/300
#  - 1s - loss: 6.8966e-04 - val_loss: 0.0026
# Epoch 109/300
#  - 1s - loss: 3.3599e-04 - val_loss: 0.0034
# Epoch 110/300
#  - 1s - loss: 5.1695e-04 - val_loss: 0.0022
# Epoch 111/300
#  - 1s - loss: 3.7823e-04 - val_loss: 5.1015e-04
# Epoch 112/300
#  - 1s - loss: 3.4359e-04 - val_loss: 7.3826e-04
# Epoch 113/300
#  - 1s - loss: 3.0820e-04 - val_loss: 0.0023
# Epoch 114/300
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch 115/300
#  - 1s - loss: 5.7069e-04 - val_loss: 0.0041
# Epoch 116/300
#  - 1s - loss: 4.8455e-04 - val_loss: 4.1083e-04
# Epoch 117/300
#  - 1s - loss: 5.3244e-04 - val_loss: 3.5587e-04
# Epoch 118/300
#  - 1s - loss: 2.5021e-04 - val_loss: 0.0019
# Epoch 119/300
#  - 1s - loss: 2.4643e-04 - val_loss: 0.0025
# Epoch 120/300
#  - 1s - loss: 3.0708e-04 - val_loss: 0.0064
# Epoch 121/300
#  - 1s - loss: 6.0650e-04 - val_loss: 0.0016
# Epoch 122/300
#  - 1s - loss: 5.4764e-04 - val_loss: 9.6683e-04
# Epoch 123/300
#  - 1s - loss: 8.6012e-04 - val_loss: 0.0016
# Epoch 124/300
#  - 1s - loss: 0.0014 - val_loss: 4.9447e-04
# Epoch 125/300
#  - 1s - loss: 0.0011 - val_loss: 0.0105
# Epoch 126/300
#  - 1s - loss: 9.0732e-04 - val_loss: 0.0067
# Epoch 127/300
#  - 1s - loss: 5.8477e-04 - val_loss: 0.0013
# Epoch 128/300
#  - 1s - loss: 5.6448e-04 - val_loss: 6.4402e-04
# Epoch 129/300
#  - 1s - loss: 3.6526e-04 - val_loss: 0.0016
# Epoch 130/300
#  - 1s - loss: 4.1352e-04 - val_loss: 0.0026
# Epoch 131/300
#  - 1s - loss: 5.9267e-04 - val_loss: 0.0015
# Epoch 132/300
#  - 1s - loss: 3.6432e-04 - val_loss: 0.0019
# Epoch 133/300
#  - 1s - loss: 2.2697e-04 - val_loss: 0.0018
# Epoch 134/300
#  - 1s - loss: 1.6123e-04 - val_loss: 0.0017
# Epoch 135/300
#  - 1s - loss: 4.3010e-04 - val_loss: 0.0034
# Epoch 136/300
#  - 1s - loss: 5.8063e-04 - val_loss: 0.0097
# Epoch 137/300
#  - 1s - loss: 4.1994e-04 - val_loss: 7.6602e-04
# Epoch 138/300
#  - 1s - loss: 5.9288e-04 - val_loss: 0.0048
# Epoch 139/300
#  - 1s - loss: 1.9642e-04 - val_loss: 0.0090
# Epoch 140/300
#  - 1s - loss: 6.8527e-04 - val_loss: 0.0051
# Epoch 141/300
#  - 1s - loss: 4.2235e-04 - val_loss: 0.0011
# Epoch 142/300
#  - 1s - loss: 4.4410e-04 - val_loss: 0.0027
# Epoch 143/300
#  - 1s - loss: 4.2571e-04 - val_loss: 0.0019
# Epoch 144/300
#  - 1s - loss: 1.6160e-04 - val_loss: 0.0014
# Epoch 145/300
#  - 1s - loss: 2.3865e-04 - val_loss: 8.9213e-04
# Epoch 146/300
#  - 1s - loss: 3.7509e-04 - val_loss: 5.2068e-04
# Epoch 147/300
#  - 1s - loss: 4.2031e-04 - val_loss: 0.0021
# Epoch 148/300
#  - 1s - loss: 2.2409e-04 - val_loss: 0.0019
# Epoch 149/300
#  - 1s - loss: 1.9006e-04 - val_loss: 5.4989e-04
# Epoch 150/300
#  - 1s - loss: 3.4289e-04 - val_loss: 0.0013
# Epoch 151/300
#  - 1s - loss: 5.2932e-04 - val_loss: 0.0015
# Epoch 152/300
#  - 1s - loss: 4.9257e-04 - val_loss: 0.0021
# Epoch 153/300
#  - 1s - loss: 8.6151e-04 - val_loss: 0.0029
# Epoch 154/300
#  - 1s - loss: 0.0011 - val_loss: 0.0023
# Epoch 155/300
#  - 1s - loss: 9.8745e-04 - val_loss: 0.0023
# Epoch 156/300
#  - 1s - loss: 7.8157e-04 - val_loss: 0.0032
# Epoch 157/300
#  - 1s - loss: 7.1862e-04 - val_loss: 6.3855e-04
# Epoch 158/300
#  - 1s - loss: 3.8279e-04 - val_loss: 0.0019
# Epoch 159/300
#  - 1s - loss: 4.0311e-04 - val_loss: 0.0083
# Epoch 160/300
#  - 1s - loss: 0.0012 - val_loss: 0.0032
# Epoch 161/300
#  - 1s - loss: 5.9429e-04 - val_loss: 0.0014
# Epoch 162/300
#  - 1s - loss: 8.6862e-04 - val_loss: 0.0029
# Epoch 163/300
#  - 1s - loss: 5.2767e-04 - val_loss: 4.1195e-04
# Epoch 164/300
#  - 1s - loss: 3.8711e-04 - val_loss: 9.0027e-04
# Epoch 165/300
#  - 1s - loss: 4.5388e-04 - val_loss: 6.7075e-04
# Epoch 166/300
#  - 1s - loss: 3.3100e-04 - val_loss: 5.9264e-04
# Epoch 167/300
#  - 1s - loss: 2.7508e-04 - val_loss: 8.1424e-04
# Epoch 168/300
#  - 1s - loss: 2.9931e-04 - val_loss: 0.0047
# Epoch 169/300
#  - 1s - loss: 3.0523e-04 - val_loss: 0.0072
# Epoch 170/300
#  - 1s - loss: 0.0018 - val_loss: 0.0105
# Epoch 171/300
#  - 1s - loss: 0.0017 - val_loss: 0.0012
# Epoch 172/300
#  - 1s - loss: 0.0013 - val_loss: 0.0077
# Epoch 173/300
#  - 1s - loss: 9.2365e-04 - val_loss: 0.0211
# Epoch 174/300
#  - 1s - loss: 8.4582e-04 - val_loss: 0.0132
# Epoch 175/300
#  - 1s - loss: 0.0013 - val_loss: 0.0058
# Epoch 176/300
#  - 1s - loss: 0.0011 - val_loss: 0.0073
# Epoch 177/300
#  - 1s - loss: 9.9490e-04 - val_loss: 0.0121
# Epoch 178/300
#  - 1s - loss: 3.8681e-04 - val_loss: 0.0062
# Epoch 179/300
#  - 1s - loss: 6.1772e-04 - val_loss: 0.0033
# Epoch 180/300
#  - 1s - loss: 6.9617e-04 - val_loss: 0.0042
# Epoch 181/300
#  - 1s - loss: 7.6032e-04 - val_loss: 8.3443e-04
# Epoch 182/300
#  - 1s - loss: 6.6659e-04 - val_loss: 0.0043
# Epoch 183/300
#  - 1s - loss: 0.0011 - val_loss: 0.0052
# Epoch 184/300
#  - 1s - loss: 0.0014 - val_loss: 0.0023
# Epoch 185/300
#  - 1s - loss: 4.3338e-04 - val_loss: 9.4235e-04
# Epoch 186/300
#  - 1s - loss: 4.6695e-04 - val_loss: 0.0016
# Epoch 187/300
#  - 1s - loss: 4.3412e-04 - val_loss: 0.0041
# Epoch 188/300
#  - 1s - loss: 5.1039e-04 - val_loss: 3.1971e-04
# Epoch 189/300
#  - 1s - loss: 3.2143e-04 - val_loss: 3.1345e-04
# Epoch 190/300
#  - 1s - loss: 2.5201e-04 - val_loss: 5.8811e-04
# Epoch 191/300
#  - 1s - loss: 3.3150e-04 - val_loss: 3.7667e-04
# Epoch 192/300
#  - 1s - loss: 2.8817e-04 - val_loss: 0.0012
# Epoch 193/300
#  - 1s - loss: 2.5848e-04 - val_loss: 0.0036
# Epoch 194/300
#  - 1s - loss: 3.5670e-04 - val_loss: 0.0025
# Epoch 195/300
#  - 1s - loss: 1.7907e-04 - val_loss: 0.0011
# Epoch 196/300
#  - 1s - loss: 2.1463e-04 - val_loss: 0.0011
# Epoch 197/300
#  - 1s - loss: 3.4156e-04 - val_loss: 5.4026e-04
# Epoch 198/300
#  - 1s - loss: 2.4456e-04 - val_loss: 0.0015
# Epoch 199/300
#  - 1s - loss: 4.2289e-04 - val_loss: 4.5720e-04
# Epoch 200/300
#  - 1s - loss: 4.1753e-04 - val_loss: 7.1596e-04
# Epoch 201/300
#  - 1s - loss: 3.3600e-04 - val_loss: 0.0042
# Epoch 202/300
#  - 1s - loss: 1.5830e-04 - val_loss: 2.6015e-04
# Epoch 203/300
#  - 1s - loss: 1.9273e-04 - val_loss: 0.0035
# Epoch 204/300
#  - 1s - loss: 3.7744e-04 - val_loss: 0.0026
# Epoch 205/300
#  - 1s - loss: 4.6279e-04 - val_loss: 0.0045
# Epoch 206/300
#  - 1s - loss: 5.0516e-04 - val_loss: 0.0031
# Epoch 207/300
#  - 1s - loss: 3.6927e-04 - val_loss: 5.4626e-04
# Epoch 208/300
#  - 1s - loss: 3.6937e-04 - val_loss: 0.0012
# Epoch 209/300
#  - 1s - loss: 6.2210e-04 - val_loss: 0.0016
# Epoch 210/300
#  - 1s - loss: 6.6762e-04 - val_loss: 0.0031
# Epoch 211/300
#  - 1s - loss: 3.9157e-04 - val_loss: 0.0034
# Epoch 212/300
#  - 1s - loss: 3.3978e-04 - val_loss: 0.0034
# Epoch 213/300
#  - 1s - loss: 2.7640e-04 - val_loss: 0.0015
# Epoch 214/300
#  - 1s - loss: 4.4730e-04 - val_loss: 0.0011
# Epoch 215/300
#  - 1s - loss: 2.5567e-04 - val_loss: 0.0043
# Epoch 216/300
#  - 1s - loss: 2.3234e-04 - val_loss: 6.4020e-04
# Epoch 217/300
#  - 1s - loss: 2.4123e-04 - val_loss: 4.2512e-04
# Epoch 218/300
#  - 1s - loss: 5.2108e-04 - val_loss: 0.0074
# Epoch 219/300
#  - 1s - loss: 6.7464e-04 - val_loss: 8.2535e-04
# Epoch 220/300
#  - 1s - loss: 9.4944e-04 - val_loss: 0.0022
# Epoch 221/300
#  - 1s - loss: 6.6116e-04 - val_loss: 0.0015
# Epoch 222/300
#  - 1s - loss: 9.2869e-04 - val_loss: 0.0079
# Epoch 223/300
#  - 1s - loss: 6.8451e-04 - val_loss: 0.0034
# Epoch 224/300
#  - 1s - loss: 5.7439e-04 - val_loss: 0.0076
# Epoch 225/300
#  - 1s - loss: 4.7401e-04 - val_loss: 0.0013
# Epoch 226/300
#  - 1s - loss: 5.7366e-04 - val_loss: 0.0021
# Epoch 227/300
#  - 1s - loss: 5.2228e-04 - val_loss: 6.8801e-04
# Epoch 228/300
#  - 1s - loss: 4.1673e-04 - val_loss: 9.0822e-04
# Epoch 229/300
#  - 1s - loss: 3.8940e-04 - val_loss: 0.0015
# Epoch 230/300
#  - 1s - loss: 4.5579e-04 - val_loss: 0.0011
# Epoch 231/300
#  - 1s - loss: 3.4815e-04 - val_loss: 0.0032
# Epoch 232/300
#  - 1s - loss: 3.2084e-04 - val_loss: 0.0012
# Epoch 233/300
#  - 1s - loss: 7.5066e-04 - val_loss: 0.0102
# Epoch 234/300
#  - 1s - loss: 5.8349e-04 - val_loss: 6.0666e-04
# Epoch 235/300
#  - 1s - loss: 4.5082e-04 - val_loss: 0.0024
# Epoch 236/300
#  - 1s - loss: 6.9283e-04 - val_loss: 0.0052
# Epoch 237/300
#  - 1s - loss: 0.0011 - val_loss: 0.0049
# Epoch 238/300
#  - 1s - loss: 6.1246e-04 - val_loss: 0.0013
# Epoch 239/300
#  - 1s - loss: 5.6938e-04 - val_loss: 0.0017
# Epoch 240/300
#  - 1s - loss: 4.5095e-04 - val_loss: 7.5417e-04
# Epoch 241/300
#  - 1s - loss: 2.5624e-04 - val_loss: 0.0042
# Epoch 242/300
#  - 1s - loss: 8.2748e-04 - val_loss: 0.0018
# Epoch 243/300
#  - 1s - loss: 3.6439e-04 - val_loss: 0.0030
# Epoch 244/300
#  - 1s - loss: 3.2113e-04 - val_loss: 0.0021
# Epoch 245/300
#  - 1s - loss: 3.1257e-04 - val_loss: 0.0018
# Epoch 246/300
#  - 1s - loss: 1.7995e-04 - val_loss: 8.3676e-04
# Epoch 247/300
#  - 1s - loss: 1.9495e-04 - val_loss: 3.6502e-04
# Epoch 248/300
#  - 1s - loss: 1.7575e-04 - val_loss: 0.0010
# Epoch 249/300
#  - 1s - loss: 1.6985e-04 - val_loss: 3.2220e-04
# Epoch 250/300
#  - 1s - loss: 1.3983e-04 - val_loss: 4.0331e-04
# Epoch 251/300
#  - 1s - loss: 2.7992e-04 - val_loss: 0.0019
# Epoch 252/300
#  - 1s - loss: 8.2317e-04 - val_loss: 0.0022
# Epoch 253/300
#  - 1s - loss: 3.6265e-04 - val_loss: 6.4433e-04
# Epoch 254/300
#  - 1s - loss: 3.8261e-04 - val_loss: 6.4275e-04
# Epoch 255/300
#  - 1s - loss: 3.3556e-04 - val_loss: 9.8288e-04
# Epoch 256/300
#  - 1s - loss: 2.2114e-04 - val_loss: 0.0019
# Epoch 257/300
#  - 1s - loss: 3.1808e-04 - val_loss: 0.0025
# Epoch 258/300
#  - 1s - loss: 2.2924e-04 - val_loss: 0.0054
# Epoch 259/300
#  - 1s - loss: 1.9934e-04 - val_loss: 0.0013
# Epoch 260/300
#  - 1s - loss: 1.8020e-04 - val_loss: 0.0060
# Epoch 261/300
#  - 1s - loss: 3.2811e-04 - val_loss: 3.7923e-04
# Epoch 262/300
#  - 1s - loss: 3.3283e-04 - val_loss: 0.0156
# Epoch 263/300
#  - 1s - loss: 2.7855e-04 - val_loss: 0.0108
# Epoch 264/300
#  - 1s - loss: 1.3741e-04 - val_loss: 0.0050
# Epoch 265/300
#  - 1s - loss: 9.5755e-05 - val_loss: 0.0030
# Epoch 266/300
#  - 1s - loss: 1.9482e-04 - val_loss: 0.0030
# Epoch 267/300
#  - 1s - loss: 3.5322e-04 - val_loss: 0.0021
# Epoch 268/300
#  - 1s - loss: 4.7095e-04 - val_loss: 0.0027
# Epoch 269/300
#  - 1s - loss: 3.8466e-04 - val_loss: 0.0039
# Epoch 270/300
#  - 1s - loss: 5.5900e-04 - val_loss: 0.0012
# Epoch 271/300
#  - 1s - loss: 7.7756e-04 - val_loss: 0.0056
# Epoch 272/300
#  - 1s - loss: 5.3381e-04 - val_loss: 4.6057e-04
# Epoch 273/300
#  - 1s - loss: 4.4253e-04 - val_loss: 0.0021
# Epoch 274/300
#  - 1s - loss: 3.6426e-04 - val_loss: 0.0029
# Epoch 275/300
#  - 1s - loss: 1.8087e-04 - val_loss: 0.0013
# Epoch 276/300
#  - 1s - loss: 3.5585e-04 - val_loss: 0.0014
# Epoch 277/300
#  - 1s - loss: 4.2248e-04 - val_loss: 4.7288e-04
# Epoch 278/300
#  - 1s - loss: 2.3914e-04 - val_loss: 5.9418e-04
# Epoch 279/300
#  - 1s - loss: 2.9403e-04 - val_loss: 0.0019
# Epoch 280/300
#  - 1s - loss: 5.1342e-04 - val_loss: 0.0019
# Epoch 281/300
#  - 1s - loss: 6.1380e-04 - val_loss: 0.0060
# Epoch 282/300
#  - 1s - loss: 5.6034e-04 - val_loss: 0.0020
# Epoch 283/300
#  - 1s - loss: 3.0116e-04 - val_loss: 0.0062
# Epoch 284/300
#  - 1s - loss: 4.6836e-04 - val_loss: 0.0023
# Epoch 285/300
#  - 1s - loss: 4.0826e-04 - val_loss: 0.0050
# Epoch 286/300
#  - 1s - loss: 5.6808e-04 - val_loss: 0.0039
# Epoch 287/300
#  - 1s - loss: 2.8323e-04 - val_loss: 0.0023
# Epoch 288/300
#  - 1s - loss: 1.7202e-04 - val_loss: 2.6057e-04
# Epoch 289/300
#  - 1s - loss: 1.5029e-04 - val_loss: 1.9074e-04
# Epoch 290/300
#  - 1s - loss: 1.1536e-04 - val_loss: 0.0011
# Epoch 291/300
#  - 1s - loss: 2.0525e-04 - val_loss: 2.5471e-04
# Epoch 292/300
#  - 1s - loss: 2.2963e-04 - val_loss: 5.0707e-04
# Epoch 293/300
#  - 1s - loss: 2.1841e-04 - val_loss: 0.0022
# Epoch 294/300
#  - 1s - loss: 3.0896e-04 - val_loss: 2.4252e-04
# Epoch 295/300
#  - 1s - loss: 1.7059e-04 - val_loss: 0.0021
# Epoch 296/300
#  - 1s - loss: 1.3879e-04 - val_loss: 0.0011
# Epoch 297/300
#  - 1s - loss: 1.4933e-04 - val_loss: 2.5846e-04
# Epoch 298/300
#  - 1s - loss: 2.1478e-04 - val_loss: 0.0022
# Epoch 299/300
#  - 1s - loss: 4.5250e-04 - val_loss: 0.0015
# Epoch 300/300
#  - 1s - loss: 0.0012 - val_loss: 0.0032
# loss: 287323309132.06854
# 정답(original): [   0.  -400.    50.     0.4]
# 예측값(original): [   0.65144205 -399.34787     225.8228      -13.059822  ]
# 0.0005720167682537316
# 185063.4431909933
# (2800, 4)
# 1.671197659023079
# 23.33081028058233
# 0.03122644728963107
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 373, 5, 19)        76
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 373, 5, 19)        76
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 186, 5, 19)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 184, 5, 38)        2204
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 184, 5, 38)        152
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 92, 5, 38)         0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 90, 5, 76)         8740
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 90, 5, 76)         304
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 45, 5, 76)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 43, 5, 152)        34808
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 43, 5, 152)        608
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 21, 5, 152)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 19, 5, 304)        138928
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 19, 5, 304)        1216
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 9, 5, 304)         0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 7, 5, 608)         555104
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 7, 5, 608)         2432
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 3, 5, 608)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 9120)              0
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               1167488
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_45 (Dense)             (None, 84)                5460
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2720
# _________________________________________________________________
# dense_47 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_48 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 1,929,168
# Trainable params: 1,926,774
# Non-trainable params: 2,394
# _________________________________________________________________
# Train on 1792 samples, validate on 448 samples
# Epoch 1/300
#  - 2s - loss: 0.1201 - val_loss: 0.2673
# Epoch 2/300
#  - 1s - loss: 0.0175 - val_loss: 0.3059
# Epoch 3/300
#  - 1s - loss: 0.0055 - val_loss: 0.3893
# Epoch 4/300
#  - 1s - loss: 0.0035 - val_loss: 0.5089
# Epoch 5/300
#  - 1s - loss: 0.0020 - val_loss: 0.4692
# Epoch 6/300
#  - 1s - loss: 0.0014 - val_loss: 0.3129
# Epoch 7/300
#  - 1s - loss: 0.0015 - val_loss: 0.1105
# Epoch 8/300
#  - 1s - loss: 0.0028 - val_loss: 0.0652
# Epoch 9/300
#  - 1s - loss: 0.0021 - val_loss: 0.0432
# Epoch 10/300
#  - 1s - loss: 0.0017 - val_loss: 0.0634
# Epoch 11/300
#  - 1s - loss: 6.9519e-04 - val_loss: 0.0527
# Epoch 12/300
#  - 1s - loss: 6.8945e-04 - val_loss: 0.0334
# Epoch 13/300
#  - 1s - loss: 8.8399e-04 - val_loss: 0.0156
# Epoch 14/300
#  - 1s - loss: 7.3160e-04 - val_loss: 0.0034
# Epoch 15/300
#  - 1s - loss: 0.0012 - val_loss: 0.0013
# Epoch 16/300
#  - 1s - loss: 9.9711e-04 - val_loss: 0.0049
# Epoch 17/300
#  - 1s - loss: 6.0604e-04 - val_loss: 0.0126
# Epoch 18/300
#  - 1s - loss: 9.1307e-04 - val_loss: 0.0165
# Epoch 19/300
#  - 1s - loss: 9.6023e-04 - val_loss: 0.0290
# Epoch 20/300
#  - 1s - loss: 0.0022 - val_loss: 0.0316
# Epoch 21/300
#  - 1s - loss: 0.0011 - val_loss: 0.0293
# Epoch 22/300
#  - 1s - loss: 0.0021 - val_loss: 0.0044
# Epoch 23/300
#  - 1s - loss: 0.0013 - val_loss: 0.0140
# Epoch 24/300
#  - 1s - loss: 8.0594e-04 - val_loss: 0.0282
# Epoch 25/300
#  - 1s - loss: 5.7575e-04 - val_loss: 0.0093
# Epoch 26/300
#  - 1s - loss: 0.0025 - val_loss: 0.0062
# Epoch 27/300
#  - 1s - loss: 0.0013 - val_loss: 0.0100
# Epoch 28/300
#  - 1s - loss: 0.0015 - val_loss: 0.0040
# Epoch 29/300
#  - 1s - loss: 9.4544e-04 - val_loss: 0.0011
# Epoch 30/300
#  - 1s - loss: 9.5267e-04 - val_loss: 0.0018
# Epoch 31/300
#  - 1s - loss: 5.9520e-04 - val_loss: 8.4186e-04
# Epoch 32/300
#  - 1s - loss: 3.3101e-04 - val_loss: 0.0011
# Epoch 33/300
#  - 1s - loss: 6.1484e-04 - val_loss: 0.0012
# Epoch 34/300
#  - 1s - loss: 3.7131e-04 - val_loss: 0.0013
# Epoch 35/300
#  - 1s - loss: 6.5118e-04 - val_loss: 0.0018
# Epoch 36/300
#  - 1s - loss: 4.6456e-04 - val_loss: 0.0012
# Epoch 37/300
#  - 1s - loss: 4.2937e-04 - val_loss: 8.2205e-04
# Epoch 38/300
#  - 1s - loss: 8.5370e-04 - val_loss: 0.0022
# Epoch 39/300
#  - 1s - loss: 0.0015 - val_loss: 0.0101
# Epoch 40/300
#  - 1s - loss: 0.0012 - val_loss: 0.0123
# Epoch 41/300
#  - 1s - loss: 3.8533e-04 - val_loss: 0.0117
# Epoch 42/300
#  - 1s - loss: 4.9371e-04 - val_loss: 0.0069
# Epoch 43/300
#  - 1s - loss: 3.5718e-04 - val_loss: 0.0047
# Epoch 44/300
#  - 1s - loss: 3.5767e-04 - val_loss: 0.0046
# Epoch 45/300
#  - 1s - loss: 3.3774e-04 - val_loss: 0.0024
# Epoch 46/300
#  - 1s - loss: 6.7706e-04 - val_loss: 4.8766e-04
# Epoch 47/300
#  - 1s - loss: 2.2346e-04 - val_loss: 5.2843e-04
# Epoch 48/300
#  - 1s - loss: 5.2052e-04 - val_loss: 4.4845e-04
# Epoch 49/300
#  - 1s - loss: 3.0164e-04 - val_loss: 5.5525e-04
# Epoch 50/300
#  - 1s - loss: 2.8418e-04 - val_loss: 3.9875e-04
# Epoch 51/300
#  - 1s - loss: 8.4102e-04 - val_loss: 5.3060e-04
# Epoch 52/300
#  - 1s - loss: 8.1655e-04 - val_loss: 0.0021
# Epoch 53/300
#  - 1s - loss: 6.2040e-04 - val_loss: 0.0014
# Epoch 54/300
#  - 1s - loss: 4.4360e-04 - val_loss: 5.3244e-04
# Epoch 55/300
#  - 1s - loss: 6.2308e-04 - val_loss: 3.3429e-04
# Epoch 56/300
#  - 1s - loss: 5.2657e-04 - val_loss: 0.0095
# Epoch 57/300
#  - 1s - loss: 5.5850e-04 - val_loss: 0.0104
# Epoch 58/300
#  - 1s - loss: 0.0011 - val_loss: 9.5517e-04
# Epoch 59/300
#  - 1s - loss: 9.9542e-04 - val_loss: 0.0022
# Epoch 60/300
#  - 1s - loss: 0.0032 - val_loss: 0.0016
# Epoch 61/300
#  - 1s - loss: 0.0015 - val_loss: 0.0057
# Epoch 62/300
#  - 1s - loss: 9.3053e-04 - val_loss: 0.0170
# Epoch 63/300
#  - 1s - loss: 5.9700e-04 - val_loss: 0.0172
# Epoch 64/300
#  - 1s - loss: 4.5461e-04 - val_loss: 0.0116
# Epoch 65/300
#  - 1s - loss: 3.6755e-04 - val_loss: 0.0097
# Epoch 66/300
#  - 1s - loss: 6.2030e-04 - val_loss: 0.0035
# Epoch 67/300
#  - 1s - loss: 3.3808e-04 - val_loss: 0.0016
# Epoch 68/300
#  - 1s - loss: 3.5650e-04 - val_loss: 2.6552e-04
# Epoch 69/300
#  - 1s - loss: 2.6906e-04 - val_loss: 8.8964e-04
# Epoch 70/300
#  - 1s - loss: 4.4310e-04 - val_loss: 4.8910e-04
# Epoch 71/300
#  - 1s - loss: 1.8585e-04 - val_loss: 3.1629e-04
# Epoch 72/300
#  - 1s - loss: 1.3930e-04 - val_loss: 0.0030
# Epoch 73/300
#  - 1s - loss: 0.0010 - val_loss: 0.0013
# Epoch 74/300
#  - 1s - loss: 6.3834e-04 - val_loss: 0.0013
# Epoch 75/300
#  - 1s - loss: 4.8840e-04 - val_loss: 2.8817e-04
# Epoch 76/300
#  - 1s - loss: 6.2449e-04 - val_loss: 3.5686e-04
# Epoch 77/300
#  - 1s - loss: 7.6449e-04 - val_loss: 3.4129e-04
# Epoch 78/300
#  - 1s - loss: 1.8900e-04 - val_loss: 9.0556e-05
# Epoch 79/300
#  - 1s - loss: 2.5699e-04 - val_loss: 2.7576e-04
# Epoch 80/300
#  - 1s - loss: 4.9010e-04 - val_loss: 0.0032
# Epoch 81/300
#  - 1s - loss: 0.0019 - val_loss: 0.0048
# Epoch 82/300
#  - 1s - loss: 0.0021 - val_loss: 0.0039
# Epoch 83/300
#  - 1s - loss: 7.7721e-04 - val_loss: 0.0051
# Epoch 84/300
#  - 1s - loss: 7.5800e-04 - val_loss: 0.0055
# Epoch 85/300
#  - 1s - loss: 2.3207e-04 - val_loss: 0.0022
# Epoch 86/300
#  - 1s - loss: 2.2734e-04 - val_loss: 7.1498e-04
# Epoch 87/300
#  - 1s - loss: 6.7228e-04 - val_loss: 0.0026
# Epoch 88/300
#  - 1s - loss: 0.0050 - val_loss: 0.0677
# Epoch 89/300
#  - 1s - loss: 0.0014 - val_loss: 0.2165
# Epoch 90/300
#  - 1s - loss: 0.0015 - val_loss: 0.1668
# Epoch 91/300
#  - 1s - loss: 0.0014 - val_loss: 0.1386
# Epoch 92/300
#  - 1s - loss: 5.5689e-04 - val_loss: 0.0957
# Epoch 93/300
#  - 1s - loss: 6.9791e-04 - val_loss: 0.0589
# Epoch 94/300
#  - 1s - loss: 0.0015 - val_loss: 0.0617
# Epoch 95/300
#  - 1s - loss: 5.0546e-04 - val_loss: 0.0364
# Epoch 96/300
#  - 1s - loss: 6.8009e-04 - val_loss: 0.0453
# Epoch 97/300
#  - 1s - loss: 6.0075e-04 - val_loss: 0.0206
# Epoch 98/300
#  - 1s - loss: 5.0626e-04 - val_loss: 0.0047
# Epoch 99/300
#  - 1s - loss: 5.1805e-04 - val_loss: 0.0159
# Epoch 100/300
#  - 1s - loss: 8.6178e-04 - val_loss: 0.0101
# Epoch 101/300
#  - 1s - loss: 6.7931e-04 - val_loss: 0.0039
# Epoch 102/300
#  - 1s - loss: 6.1483e-04 - val_loss: 7.8525e-04
# Epoch 103/300
#  - 1s - loss: 2.1092e-04 - val_loss: 0.0033
# Epoch 104/300
#  - 1s - loss: 2.7336e-04 - val_loss: 8.3265e-04
# Epoch 105/300
#  - 1s - loss: 2.8454e-04 - val_loss: 1.6477e-04
# Epoch 106/300
#  - 1s - loss: 0.0014 - val_loss: 0.0026
# Epoch 107/300
#  - 1s - loss: 0.0012 - val_loss: 0.0050
# Epoch 108/300
#  - 1s - loss: 7.5347e-04 - val_loss: 0.0018
# Epoch 109/300
#  - 1s - loss: 5.8236e-04 - val_loss: 1.5211e-04
# Epoch 110/300
#  - 1s - loss: 2.4368e-04 - val_loss: 8.3190e-04
# Epoch 111/300
#  - 1s - loss: 0.0012 - val_loss: 0.0021
# Epoch 112/300
#  - 1s - loss: 9.3144e-04 - val_loss: 3.9797e-04
# Epoch 113/300
#  - 1s - loss: 8.2747e-04 - val_loss: 0.0012
# Epoch 114/300
#  - 1s - loss: 6.5396e-04 - val_loss: 0.0016
# Epoch 115/300
#  - 1s - loss: 4.0955e-04 - val_loss: 6.9171e-04
# Epoch 116/300
#  - 1s - loss: 4.9981e-04 - val_loss: 2.0787e-04
# Epoch 117/300
#  - 1s - loss: 4.7621e-04 - val_loss: 0.0021
# Epoch 118/300
#  - 1s - loss: 3.8519e-04 - val_loss: 0.0013
# Epoch 119/300
#  - 1s - loss: 5.9699e-04 - val_loss: 6.3313e-04
# Epoch 120/300
#  - 1s - loss: 5.0611e-04 - val_loss: 1.2379e-04
# Epoch 121/300
#  - 1s - loss: 8.8125e-04 - val_loss: 0.0015
# Epoch 122/300
#  - 1s - loss: 6.6255e-04 - val_loss: 0.0015
# Epoch 123/300
#  - 1s - loss: 7.6563e-04 - val_loss: 0.0016
# Epoch 124/300
#  - 1s - loss: 0.0021 - val_loss: 0.0030
# Epoch 125/300
#  - 1s - loss: 0.0021 - val_loss: 0.0011
# Epoch 126/300
#  - 1s - loss: 8.6133e-04 - val_loss: 0.0020
# Epoch 127/300
#  - 1s - loss: 0.0011 - val_loss: 0.0025
# Epoch 128/300
#  - 1s - loss: 5.1502e-04 - val_loss: 4.3274e-04
# Epoch 129/300
#  - 1s - loss: 1.9294e-04 - val_loss: 2.9996e-04
# Epoch 130/300
#  - 1s - loss: 3.9556e-04 - val_loss: 1.4940e-04
# Epoch 131/300
#  - 1s - loss: 1.4747e-04 - val_loss: 5.8752e-04
# Epoch 132/300
#  - 1s - loss: 4.1972e-04 - val_loss: 4.0000e-04
# Epoch 133/300
#  - 1s - loss: 3.0574e-04 - val_loss: 7.8882e-04
# Epoch 134/300
#  - 1s - loss: 2.2233e-04 - val_loss: 0.0011
# Epoch 135/300
#  - 1s - loss: 4.1786e-04 - val_loss: 2.4331e-04
# Epoch 136/300
#  - 1s - loss: 5.8340e-04 - val_loss: 3.1845e-04
# Epoch 137/300
#  - 1s - loss: 8.1849e-04 - val_loss: 0.0031
# Epoch 138/300
#  - 1s - loss: 7.4746e-04 - val_loss: 0.0011
# Epoch 139/300
#  - 1s - loss: 6.3299e-04 - val_loss: 1.9743e-04
# Epoch 140/300
#  - 1s - loss: 2.6217e-04 - val_loss: 4.8194e-04
# Epoch 141/300
#  - 1s - loss: 2.7076e-04 - val_loss: 1.4217e-04
# Epoch 142/300
#  - 1s - loss: 1.9059e-04 - val_loss: 1.4561e-04
# Epoch 143/300
#  - 1s - loss: 1.4760e-04 - val_loss: 1.5135e-04
# Epoch 144/300
#  - 1s - loss: 2.9899e-04 - val_loss: 6.4398e-04
# Epoch 145/300
#  - 1s - loss: 2.8843e-04 - val_loss: 9.8636e-04
# Epoch 146/300
#  - 1s - loss: 3.1028e-04 - val_loss: 1.9194e-04
# Epoch 147/300
#  - 1s - loss: 2.6612e-04 - val_loss: 2.7968e-04
# Epoch 148/300
#  - 1s - loss: 2.5485e-04 - val_loss: 0.0022
# Epoch 149/300
#  - 1s - loss: 0.0021 - val_loss: 0.0020
# Epoch 150/300
#  - 1s - loss: 0.0011 - val_loss: 0.0070
# Epoch 151/300
#  - 1s - loss: 5.6633e-04 - val_loss: 0.0023
# Epoch 152/300
#  - 1s - loss: 4.8010e-04 - val_loss: 5.2370e-04
# Epoch 153/300
#  - 1s - loss: 3.3874e-04 - val_loss: 0.0016
# Epoch 154/300
#  - 1s - loss: 3.5856e-04 - val_loss: 4.5640e-04
# Epoch 155/300
#  - 1s - loss: 0.0011 - val_loss: 0.0058
# Epoch 156/300
#  - 1s - loss: 4.6501e-04 - val_loss: 0.0021
# Epoch 157/300
#  - 1s - loss: 2.0487e-04 - val_loss: 0.0014
# Epoch 158/300
#  - 1s - loss: 2.0526e-04 - val_loss: 0.0021
# Epoch 159/300
#  - 1s - loss: 3.3808e-04 - val_loss: 0.0011
# Epoch 160/300
#  - 1s - loss: 2.3055e-04 - val_loss: 0.0013
# Epoch 161/300
#  - 1s - loss: 2.3547e-04 - val_loss: 2.7704e-04
# Epoch 162/300
#  - 1s - loss: 4.6456e-04 - val_loss: 1.3849e-04
# Epoch 163/300
#  - 1s - loss: 2.0964e-04 - val_loss: 4.7604e-04
# Epoch 164/300
#  - 1s - loss: 2.8332e-04 - val_loss: 1.2231e-04
# Epoch 165/300
#  - 1s - loss: 1.4041e-04 - val_loss: 0.0015
# Epoch 166/300
#  - 1s - loss: 4.9160e-04 - val_loss: 1.9147e-04
# Epoch 167/300
#  - 1s - loss: 3.9191e-04 - val_loss: 2.1135e-04
# Epoch 168/300
#  - 1s - loss: 2.9841e-04 - val_loss: 1.3168e-04
# Epoch 169/300
#  - 1s - loss: 3.3387e-04 - val_loss: 1.5551e-04
# Epoch 170/300
#  - 1s - loss: 3.9672e-04 - val_loss: 0.0036
# Epoch 171/300
#  - 1s - loss: 6.2947e-04 - val_loss: 2.6427e-04
# Epoch 172/300
#  - 1s - loss: 3.7469e-04 - val_loss: 7.3404e-04
# Epoch 173/300
#  - 1s - loss: 0.0014 - val_loss: 0.0045
# Epoch 174/300
#  - 1s - loss: 5.3494e-04 - val_loss: 0.0047
# Epoch 175/300
#  - 1s - loss: 5.2952e-04 - val_loss: 8.2075e-04
# Epoch 176/300
#  - 1s - loss: 5.5759e-04 - val_loss: 8.9918e-04
# Epoch 177/300
#  - 1s - loss: 4.2945e-04 - val_loss: 0.0047
# Epoch 178/300
#  - 1s - loss: 4.8846e-04 - val_loss: 6.7331e-04
# Epoch 179/300
#  - 1s - loss: 2.1543e-04 - val_loss: 1.1190e-04
# Epoch 180/300
#  - 1s - loss: 3.2508e-04 - val_loss: 7.5468e-04
# Epoch 181/300
#  - 1s - loss: 4.6098e-04 - val_loss: 5.0188e-05
# Epoch 182/300
#  - 1s - loss: 3.3950e-04 - val_loss: 1.6566e-04
# Epoch 183/300
#  - 1s - loss: 3.0282e-04 - val_loss: 6.1024e-04
# Epoch 184/300
#  - 1s - loss: 4.0624e-04 - val_loss: 3.8692e-04
# Epoch 185/300
#  - 1s - loss: 5.1743e-04 - val_loss: 2.4318e-04
# Epoch 186/300
#  - 1s - loss: 3.1714e-04 - val_loss: 1.6772e-04
# Epoch 187/300
#  - 1s - loss: 3.6604e-04 - val_loss: 0.0013
# Epoch 188/300
#  - 1s - loss: 4.0479e-04 - val_loss: 3.1686e-04
# Epoch 189/300
#  - 1s - loss: 1.7575e-04 - val_loss: 2.0143e-04
# Epoch 190/300
#  - 1s - loss: 3.6754e-04 - val_loss: 0.0026
# Epoch 191/300
#  - 1s - loss: 6.2625e-04 - val_loss: 4.6067e-04
# Epoch 192/300
#  - 1s - loss: 2.3856e-04 - val_loss: 9.3225e-04
# Epoch 193/300
#  - 1s - loss: 6.0092e-04 - val_loss: 5.9769e-04
# Epoch 194/300
#  - 1s - loss: 4.4692e-04 - val_loss: 2.1308e-04
# Epoch 195/300
#  - 1s - loss: 3.1305e-04 - val_loss: 9.6869e-05
# Epoch 196/300
#  - 1s - loss: 2.2116e-04 - val_loss: 2.4935e-04
# Epoch 197/300
#  - 1s - loss: 8.4136e-05 - val_loss: 5.6846e-04
# Epoch 198/300
#  - 1s - loss: 1.3072e-04 - val_loss: 1.3242e-04
# Epoch 199/300
#  - 1s - loss: 1.9567e-04 - val_loss: 1.8085e-04
# Epoch 200/300
#  - 1s - loss: 2.1585e-04 - val_loss: 8.7127e-05
# Epoch 201/300
#  - 1s - loss: 6.3488e-04 - val_loss: 8.0708e-05
# Epoch 202/300
#  - 1s - loss: 4.1489e-04 - val_loss: 0.0011
# Epoch 203/300
#  - 1s - loss: 4.1464e-04 - val_loss: 0.0014
# Epoch 204/300
#  - 1s - loss: 6.1967e-04 - val_loss: 0.0012
# Epoch 205/300
#  - 1s - loss: 5.8818e-04 - val_loss: 2.6466e-04
# Epoch 206/300
#  - 1s - loss: 4.5756e-04 - val_loss: 3.1745e-04
# Epoch 207/300
#  - 1s - loss: 4.5423e-04 - val_loss: 2.7665e-04
# Epoch 208/300
#  - 1s - loss: 2.3921e-04 - val_loss: 5.8665e-05
# Epoch 209/300
#  - 1s - loss: 3.0918e-04 - val_loss: 4.6666e-04
# Epoch 210/300
#  - 1s - loss: 2.9139e-04 - val_loss: 0.0018
# Epoch 211/300
#  - 1s - loss: 7.0179e-04 - val_loss: 2.3520e-04
# Epoch 212/300
#  - 1s - loss: 1.9867e-04 - val_loss: 1.8564e-04
# Epoch 213/300
#  - 1s - loss: 4.4520e-04 - val_loss: 1.9031e-04
# Epoch 214/300
#  - 1s - loss: 6.9289e-04 - val_loss: 0.0020
# Epoch 215/300
#  - 1s - loss: 6.9703e-04 - val_loss: 2.5785e-04
# Epoch 216/300
#  - 1s - loss: 4.8039e-04 - val_loss: 0.0034
# Epoch 217/300
#  - 1s - loss: 7.1696e-04 - val_loss: 7.9490e-05
# Epoch 218/300
#  - 1s - loss: 4.4680e-04 - val_loss: 9.3808e-05
# Epoch 219/300
#  - 1s - loss: 3.5246e-04 - val_loss: 4.9522e-04
# Epoch 220/300
#  - 1s - loss: 3.2823e-04 - val_loss: 4.8355e-05
# Epoch 221/300
#  - 1s - loss: 6.1352e-04 - val_loss: 3.5699e-04
# Epoch 222/300
#  - 1s - loss: 0.0016 - val_loss: 0.0154
# Epoch 223/300
#  - 1s - loss: 8.4358e-04 - val_loss: 0.0187
# Epoch 224/300
#  - 1s - loss: 0.0012 - val_loss: 0.0058
# Epoch 225/300
#  - 1s - loss: 6.6248e-04 - val_loss: 0.0038
# Epoch 226/300
#  - 1s - loss: 3.8303e-04 - val_loss: 0.0062
# Epoch 227/300
#  - 1s - loss: 3.6605e-04 - val_loss: 0.0078
# Epoch 228/300
#  - 1s - loss: 4.1810e-04 - val_loss: 0.0029
# Epoch 229/300
#  - 1s - loss: 3.6200e-04 - val_loss: 0.0010
# Epoch 230/300
#  - 1s - loss: 6.3271e-04 - val_loss: 0.0110
# Epoch 231/300
#  - 1s - loss: 3.8218e-04 - val_loss: 0.0095
# Epoch 232/300
#  - 1s - loss: 7.6384e-04 - val_loss: 1.8346e-04
# Epoch 233/300
#  - 1s - loss: 9.3591e-04 - val_loss: 0.0106
# Epoch 234/300
#  - 1s - loss: 1.7204e-04 - val_loss: 0.0061
# Epoch 235/300
#  - 1s - loss: 3.8804e-04 - val_loss: 8.8114e-04
# Epoch 236/300
#  - 1s - loss: 4.5630e-04 - val_loss: 0.0026
# Epoch 237/300
#  - 1s - loss: 6.5553e-04 - val_loss: 0.0048
# Epoch 238/300
#  - 1s - loss: 6.4795e-04 - val_loss: 2.4243e-04
# Epoch 239/300
#  - 1s - loss: 3.5647e-04 - val_loss: 0.0010
# Epoch 240/300
#  - 1s - loss: 2.2653e-04 - val_loss: 1.4096e-04
# Epoch 241/300
#  - 1s - loss: 2.6686e-04 - val_loss: 4.7367e-04
# Epoch 242/300
#  - 1s - loss: 9.4115e-05 - val_loss: 1.9659e-04
# Epoch 243/300
#  - 1s - loss: 3.5305e-04 - val_loss: 5.9695e-04
# Epoch 244/300
#  - 1s - loss: 2.5099e-04 - val_loss: 2.3962e-04
# Epoch 245/300
#  - 1s - loss: 2.2358e-04 - val_loss: 6.0505e-04
# Epoch 246/300
#  - 1s - loss: 2.9353e-04 - val_loss: 1.2126e-04
# Epoch 247/300
#  - 1s - loss: 3.0480e-04 - val_loss: 2.6505e-04
# Epoch 248/300
#  - 1s - loss: 1.4506e-04 - val_loss: 1.2013e-04
# Epoch 249/300
#  - 1s - loss: 1.7946e-04 - val_loss: 2.9798e-04
# Epoch 250/300
#  - 1s - loss: 3.2119e-04 - val_loss: 6.0407e-04
# Epoch 251/300
#  - 1s - loss: 4.7606e-04 - val_loss: 2.1361e-04
# Epoch 252/300
#  - 1s - loss: 2.8136e-04 - val_loss: 2.1075e-04
# Epoch 253/300
#  - 1s - loss: 5.2548e-04 - val_loss: 2.4224e-04
# Epoch 254/300
#  - 1s - loss: 4.5770e-04 - val_loss: 0.0011
# Epoch 255/300
#  - 1s - loss: 7.4783e-04 - val_loss: 9.9678e-05
# Epoch 256/300
#  - 1s - loss: 5.0283e-04 - val_loss: 7.4639e-04
# Epoch 257/300
#  - 1s - loss: 5.8977e-04 - val_loss: 1.5571e-04
# Epoch 258/300
#  - 1s - loss: 3.2155e-04 - val_loss: 1.4184e-04
# Epoch 259/300
#  - 1s - loss: 2.8960e-04 - val_loss: 3.8223e-04
# Epoch 260/300
#  - 1s - loss: 3.2302e-04 - val_loss: 0.0068
# Epoch 261/300
#  - 1s - loss: 0.0021 - val_loss: 0.0013
# Epoch 262/300
#  - 1s - loss: 0.0075 - val_loss: 0.1636
# Epoch 263/300
#  - 1s - loss: 0.0029 - val_loss: 0.1831
# Epoch 264/300
#  - 1s - loss: 0.0020 - val_loss: 0.2327
# Epoch 265/300
#  - 1s - loss: 0.0012 - val_loss: 0.1880
# Epoch 266/300
#  - 1s - loss: 5.8065e-04 - val_loss: 0.1153
# Epoch 267/300
#  - 1s - loss: 0.0021 - val_loss: 0.0786
# Epoch 268/300
#  - 1s - loss: 0.0126 - val_loss: 0.4315
# Epoch 269/300
#  - 1s - loss: 0.0045 - val_loss: 0.2590
# Epoch 270/300
#  - 1s - loss: 0.0014 - val_loss: 0.3225
# Epoch 271/300
#  - 1s - loss: 6.9141e-04 - val_loss: 0.2525
# Epoch 272/300
#  - 1s - loss: 4.3369e-04 - val_loss: 0.1845
# Epoch 273/300
#  - 1s - loss: 3.0059e-04 - val_loss: 0.1468
# Epoch 274/300
#  - 1s - loss: 3.0296e-04 - val_loss: 0.0827
# Epoch 275/300
#  - 1s - loss: 3.8238e-04 - val_loss: 0.0683
# Epoch 276/300
#  - 1s - loss: 7.3914e-04 - val_loss: 0.0465
# Epoch 277/300
#  - 1s - loss: 4.0779e-04 - val_loss: 0.0315
# Epoch 278/300
#  - 1s - loss: 3.4804e-04 - val_loss: 0.0181
# Epoch 279/300
#  - 1s - loss: 3.2791e-04 - val_loss: 0.0148
# Epoch 280/300
#  - 1s - loss: 3.2403e-04 - val_loss: 0.0088
# Epoch 281/300
#  - 1s - loss: 3.5093e-04 - val_loss: 0.0267
# Epoch 282/300
#  - 1s - loss: 0.0063 - val_loss: 0.0179
# Epoch 283/300
#  - 1s - loss: 0.0018 - val_loss: 0.0739
# Epoch 284/300
#  - 1s - loss: 8.3643e-04 - val_loss: 0.0562
# Epoch 285/300
#  - 1s - loss: 4.7737e-04 - val_loss: 0.0248
# Epoch 286/300
#  - 1s - loss: 6.8511e-04 - val_loss: 0.0085
# Epoch 287/300
#  - 1s - loss: 4.3039e-04 - val_loss: 0.0025
# Epoch 288/300
#  - 1s - loss: 9.2931e-04 - val_loss: 0.0101
# Epoch 289/300
#  - 1s - loss: 0.0016 - val_loss: 0.0037
# Epoch 290/300
#  - 1s - loss: 0.0010 - val_loss: 3.8041e-04
# Epoch 291/300
#  - 1s - loss: 0.0011 - val_loss: 0.0059
# Epoch 292/300
#  - 1s - loss: 2.5313e-04 - val_loss: 6.8336e-04
# Epoch 293/300
#  - 1s - loss: 2.5082e-04 - val_loss: 0.0013
# Epoch 294/300
#  - 1s - loss: 6.9546e-04 - val_loss: 0.0019
# Epoch 295/300
#  - 1s - loss: 4.2417e-04 - val_loss: 1.5943e-04
# Epoch 296/300
#  - 1s - loss: 5.9465e-04 - val_loss: 0.0024
# Epoch 297/300
#  - 1s - loss: 0.0011 - val_loss: 3.4149e-04
# Epoch 298/300
#  - 1s - loss: 7.6797e-04 - val_loss: 4.3339e-04
# Epoch 299/300
#  - 1s - loss: 0.0011 - val_loss: 6.3262e-04
# Epoch 300/300
#  - 1s - loss: 5.4290e-04 - val_loss: 0.0021
# loss: 227138086139143.3
# 정답(original): [   0.  -400.    50.     0.4]
# 예측값(original): [-33.05623    13.0809145  50.318687  -37.58029  ]
# 7.114170088772602
# 1.025872770785859
# (2800, 4)
# 1.1772955793342752
# 4.339243570963542
# -6.454023088727679
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_49 (Conv2D)           (None, 373, 5, 19)        76
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 373, 5, 19)        76
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 186, 5, 19)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 184, 5, 38)        2204
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 184, 5, 38)        152
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 92, 5, 38)         0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 90, 5, 76)         8740
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 90, 5, 76)         304
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 45, 5, 76)         0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 43, 5, 152)        34808
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 43, 5, 152)        608
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 21, 5, 152)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 19, 5, 304)        138928
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 19, 5, 304)        1216
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 9, 5, 304)         0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 7, 5, 608)         555104
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 7, 5, 608)         2432
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 3, 5, 608)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 9120)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 128)               1167488
# _________________________________________________________________
# dense_50 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_51 (Dense)             (None, 84)                5460
# _________________________________________________________________
# dense_52 (Dense)             (None, 32)                2720
# _________________________________________________________________
# dense_53 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_54 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 1,929,168
# Trainable params: 1,926,774
# Non-trainable params: 2,394
# _________________________________________________________________
# Train on 1792 samples, validate on 448 samples
# Epoch 1/300
#  - 2s - loss: 9.6645 - val_loss: 4.6803
# Epoch 2/300
#  - 1s - loss: 0.2097 - val_loss: 2.6889
# Epoch 3/300
#  - 1s - loss: 0.0488 - val_loss: 1.8879
# Epoch 4/300
#  - 1s - loss: 0.0189 - val_loss: 0.9865
# Epoch 5/300
#  - 1s - loss: 0.0162 - val_loss: 0.5634
# Epoch 6/300
#  - 1s - loss: 0.0139 - val_loss: 0.2550
# Epoch 7/300
#  - 1s - loss: 0.0119 - val_loss: 0.2064
# Epoch 8/300
#  - 1s - loss: 0.0101 - val_loss: 0.3030
# Epoch 9/300
#  - 1s - loss: 0.0081 - val_loss: 0.1674
# Epoch 10/300
#  - 1s - loss: 0.0104 - val_loss: 0.1068
# Epoch 11/300
#  - 1s - loss: 0.0077 - val_loss: 0.1095
# Epoch 12/300
#  - 1s - loss: 0.0060 - val_loss: 0.0708
# Epoch 13/300
#  - 1s - loss: 0.0034 - val_loss: 0.0519
# Epoch 14/300
#  - 1s - loss: 0.0046 - val_loss: 0.0434
# Epoch 15/300
#  - 1s - loss: 0.0090 - val_loss: 0.0483
# Epoch 16/300
#  - 1s - loss: 0.0051 - val_loss: 0.0306
# Epoch 17/300
#  - 1s - loss: 0.0040 - val_loss: 0.0160
# Epoch 18/300
#  - 1s - loss: 0.0055 - val_loss: 0.0148
# Epoch 19/300
#  - 1s - loss: 0.0062 - val_loss: 0.0136
# Epoch 20/300
#  - 1s - loss: 0.0031 - val_loss: 0.0061
# Epoch 21/300
#  - 1s - loss: 0.0042 - val_loss: 0.0093
# Epoch 22/300
#  - 1s - loss: 0.0053 - val_loss: 0.0059
# Epoch 23/300
#  - 1s - loss: 0.0029 - val_loss: 0.0108
# Epoch 24/300
#  - 1s - loss: 0.0034 - val_loss: 0.0071
# Epoch 25/300
#  - 1s - loss: 0.0030 - val_loss: 0.0079
# Epoch 26/300
#  - 1s - loss: 0.0025 - val_loss: 0.0037
# Epoch 27/300
#  - 1s - loss: 0.0027 - val_loss: 0.0084
# Epoch 28/300
#  - 1s - loss: 0.0054 - val_loss: 0.0036
# Epoch 29/300
#  - 1s - loss: 0.0055 - val_loss: 0.0024
# Epoch 30/300
#  - 1s - loss: 0.0030 - val_loss: 0.0021
# Epoch 31/300
#  - 1s - loss: 0.0026 - val_loss: 0.0047
# Epoch 32/300
#  - 1s - loss: 0.0021 - val_loss: 0.0052
# Epoch 33/300
#  - 1s - loss: 0.0028 - val_loss: 0.0074
# Epoch 34/300
#  - 1s - loss: 0.0031 - val_loss: 0.0036
# Epoch 35/300
#  - 1s - loss: 0.0019 - val_loss: 0.0048
# Epoch 36/300
#  - 1s - loss: 0.0031 - val_loss: 0.0027
# Epoch 37/300
#  - 1s - loss: 0.0023 - val_loss: 0.0027
# Epoch 38/300
#  - 1s - loss: 0.0038 - val_loss: 0.0074
# Epoch 39/300
#  - 1s - loss: 0.0069 - val_loss: 0.0183
# Epoch 40/300
#  - 1s - loss: 0.0076 - val_loss: 0.0052
# Epoch 41/300
#  - 1s - loss: 0.0045 - val_loss: 0.0065
# Epoch 42/300
#  - 1s - loss: 0.0031 - val_loss: 0.0021
# Epoch 43/300
#  - 1s - loss: 0.0019 - val_loss: 0.0033
# Epoch 44/300
#  - 1s - loss: 0.0016 - val_loss: 0.0040
# Epoch 45/300
#  - 1s - loss: 0.0034 - val_loss: 0.0018
# Epoch 46/300
#  - 1s - loss: 0.0022 - val_loss: 0.0029
# Epoch 47/300
#  - 1s - loss: 0.0016 - val_loss: 0.0015
# Epoch 48/300
#  - 1s - loss: 0.0015 - val_loss: 0.0047
# Epoch 49/300
#  - 1s - loss: 0.0029 - val_loss: 0.0027
# Epoch 50/300
#  - 1s - loss: 0.0019 - val_loss: 0.0018
# Epoch 51/300
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch 52/300
#  - 1s - loss: 0.0012 - val_loss: 0.0021
# Epoch 53/300
#  - 1s - loss: 0.0018 - val_loss: 0.0129
# Epoch 54/300
#  - 1s - loss: 0.0050 - val_loss: 0.0027
# Epoch 55/300
#  - 1s - loss: 0.0023 - val_loss: 0.0040
# Epoch 56/300
#  - 1s - loss: 0.0032 - val_loss: 0.0020
# Epoch 57/300
#  - 1s - loss: 0.0018 - val_loss: 0.0022
# Epoch 58/300
#  - 1s - loss: 0.0014 - val_loss: 0.0070
# Epoch 59/300
#  - 1s - loss: 0.0025 - val_loss: 0.0061
# Epoch 60/300
#  - 1s - loss: 0.0038 - val_loss: 0.0259
# Epoch 61/300
#  - 1s - loss: 0.0110 - val_loss: 0.0072
# Epoch 62/300
#  - 1s - loss: 0.0087 - val_loss: 0.0055
# Epoch 63/300
#  - 1s - loss: 0.0031 - val_loss: 0.0037
# Epoch 64/300
#  - 1s - loss: 0.0023 - val_loss: 0.0019
# Epoch 65/300
#  - 1s - loss: 0.0015 - val_loss: 0.0026
# Epoch 66/300
#  - 1s - loss: 0.0030 - val_loss: 0.0035
# Epoch 67/300
#  - 1s - loss: 0.0039 - val_loss: 0.0046
# Epoch 68/300
#  - 1s - loss: 0.0028 - val_loss: 0.0026
# Epoch 69/300
#  - 1s - loss: 0.0032 - val_loss: 0.0013
# Epoch 70/300
#  - 1s - loss: 0.0038 - val_loss: 0.0074
# Epoch 71/300
#  - 1s - loss: 0.0033 - val_loss: 0.0054
# Epoch 72/300
#  - 1s - loss: 0.0030 - val_loss: 0.0020
# Epoch 73/300
#  - 1s - loss: 0.0042 - val_loss: 0.0309
# Epoch 74/300
#  - 1s - loss: 0.0138 - val_loss: 0.0120
# Epoch 75/300
#  - 1s - loss: 0.0069 - val_loss: 0.0028
# Epoch 76/300
#  - 1s - loss: 0.0027 - val_loss: 0.0037
# Epoch 77/300
#  - 1s - loss: 0.0030 - val_loss: 0.0032
# Epoch 78/300
#  - 1s - loss: 0.0026 - val_loss: 0.0034
# Epoch 79/300
#  - 1s - loss: 0.0021 - val_loss: 0.0084
# Epoch 80/300
#  - 1s - loss: 0.0029 - val_loss: 0.0026
# Epoch 81/300
#  - 1s - loss: 0.0051 - val_loss: 0.0142
# Epoch 82/300
#  - 1s - loss: 0.0084 - val_loss: 0.0158
# Epoch 83/300
#  - 1s - loss: 0.0090 - val_loss: 0.0073
# Epoch 84/300
#  - 1s - loss: 0.0073 - val_loss: 0.0063
# Epoch 85/300
#  - 1s - loss: 0.0039 - val_loss: 0.0011
# Epoch 86/300
#  - 1s - loss: 0.0022 - val_loss: 0.0013
# Epoch 87/300
#  - 1s - loss: 0.0028 - val_loss: 0.0078
# Epoch 88/300
#  - 1s - loss: 0.0052 - val_loss: 0.0016
# Epoch 89/300
#  - 1s - loss: 0.0048 - val_loss: 0.0040
# Epoch 90/300
#  - 1s - loss: 0.0025 - val_loss: 0.0019
# Epoch 91/300
#  - 1s - loss: 0.0016 - val_loss: 0.0015
# Epoch 92/300
#  - 1s - loss: 0.0012 - val_loss: 0.0011
# Epoch 93/300
#  - 1s - loss: 0.0021 - val_loss: 0.0052
# Epoch 94/300
#  - 1s - loss: 0.0032 - val_loss: 0.0059
# Epoch 95/300
#  - 1s - loss: 0.0023 - val_loss: 0.0015
# Epoch 96/300
#  - 1s - loss: 8.6985e-04 - val_loss: 0.0012
# Epoch 97/300
#  - 1s - loss: 0.0013 - val_loss: 0.0025
# Epoch 98/300
#  - 1s - loss: 0.0026 - val_loss: 0.0014
# Epoch 99/300
#  - 1s - loss: 0.0029 - val_loss: 0.0024
# Epoch 100/300
#  - 1s - loss: 0.0019 - val_loss: 0.0025
# Epoch 101/300
#  - 1s - loss: 0.0022 - val_loss: 0.0023
# Epoch 102/300
#  - 1s - loss: 0.0015 - val_loss: 0.0041
# Epoch 103/300
#  - 1s - loss: 0.0029 - val_loss: 0.0049
# Epoch 104/300
#  - 1s - loss: 0.0039 - val_loss: 0.0281
# Epoch 105/300
#  - 1s - loss: 0.0112 - val_loss: 0.0096
# Epoch 106/300
#  - 1s - loss: 0.0087 - val_loss: 0.0155
# Epoch 107/300
#  - 1s - loss: 0.0061 - val_loss: 0.0041
# Epoch 108/300
#  - 1s - loss: 0.0026 - val_loss: 0.0125
# Epoch 109/300
#  - 1s - loss: 0.0034 - val_loss: 0.0050
# Epoch 110/300
#  - 1s - loss: 0.0043 - val_loss: 0.0029
# Epoch 111/300
#  - 1s - loss: 0.0039 - val_loss: 0.0051
# Epoch 112/300
#  - 1s - loss: 0.0036 - val_loss: 0.0032
# Epoch 113/300
#  - 1s - loss: 0.0029 - val_loss: 0.0052
# Epoch 114/300
#  - 1s - loss: 0.0022 - val_loss: 0.0029
# Epoch 115/300
#  - 1s - loss: 0.0031 - val_loss: 0.0040
# Epoch 116/300
#  - 1s - loss: 0.0016 - val_loss: 0.0051
# Epoch 117/300
#  - 1s - loss: 0.0025 - val_loss: 0.0017
# Epoch 118/300
#  - 1s - loss: 0.0013 - val_loss: 0.0024
# Epoch 119/300
#  - 1s - loss: 0.0015 - val_loss: 0.0036
# Epoch 120/300
#  - 1s - loss: 0.0018 - val_loss: 0.0011
# Epoch 121/300
#  - 1s - loss: 8.1496e-04 - val_loss: 0.0030
# Epoch 122/300
#  - 1s - loss: 0.0015 - val_loss: 0.0013
# Epoch 123/300
#  - 1s - loss: 9.2260e-04 - val_loss: 0.0015
# Epoch 124/300
#  - 1s - loss: 0.0013 - val_loss: 8.4143e-04
# Epoch 125/300
#  - 1s - loss: 9.1352e-04 - val_loss: 0.0011
# Epoch 126/300
#  - 1s - loss: 0.0010 - val_loss: 0.0024
# Epoch 127/300
#  - 1s - loss: 0.0011 - val_loss: 0.0059
# Epoch 128/300
#  - 1s - loss: 0.0028 - val_loss: 0.0039
# Epoch 129/300
#  - 1s - loss: 0.0021 - val_loss: 0.0015
# Epoch 130/300
#  - 1s - loss: 0.0010 - val_loss: 0.0014
# Epoch 131/300
#  - 1s - loss: 0.0011 - val_loss: 8.3577e-04
# Epoch 132/300
#  - 1s - loss: 0.0013 - val_loss: 9.4402e-04
# Epoch 133/300
#  - 1s - loss: 8.4976e-04 - val_loss: 0.0031
# Epoch 134/300
#  - 1s - loss: 0.0026 - val_loss: 0.0067
# Epoch 135/300
#  - 1s - loss: 0.0021 - val_loss: 0.0137
# Epoch 136/300
#  - 1s - loss: 0.0075 - val_loss: 0.0060
# Epoch 137/300
#  - 1s - loss: 0.0072 - val_loss: 0.0115
# Epoch 138/300
#  - 1s - loss: 0.0104 - val_loss: 0.0153
# Epoch 139/300
#  - 1s - loss: 0.0062 - val_loss: 0.0130
# Epoch 140/300
#  - 1s - loss: 0.0041 - val_loss: 0.0042
# Epoch 141/300
#  - 1s - loss: 0.0044 - val_loss: 0.0020
# Epoch 142/300
#  - 1s - loss: 0.0034 - val_loss: 0.0021
# Epoch 143/300
#  - 1s - loss: 0.0032 - val_loss: 0.0046
# Epoch 144/300
#  - 1s - loss: 0.0013 - val_loss: 0.0059
# Epoch 145/300
#  - 1s - loss: 0.0016 - val_loss: 0.0099
# Epoch 146/300
#  - 1s - loss: 0.0028 - val_loss: 0.0159
# Epoch 147/300
#  - 1s - loss: 0.0044 - val_loss: 0.0086
# Epoch 148/300
#  - 1s - loss: 0.0032 - val_loss: 0.0096
# Epoch 149/300
#  - 1s - loss: 0.0044 - val_loss: 0.0022
# Epoch 150/300
#  - 1s - loss: 0.0056 - val_loss: 0.0031
# Epoch 151/300
#  - 1s - loss: 0.0044 - val_loss: 0.0057
# Epoch 152/300
#  - 1s - loss: 0.0049 - val_loss: 0.0014
# Epoch 153/300
#  - 1s - loss: 0.0021 - val_loss: 0.0012
# Epoch 154/300
#  - 1s - loss: 9.6122e-04 - val_loss: 0.0037
# Epoch 155/300
#  - 1s - loss: 0.0037 - val_loss: 0.0099
# Epoch 156/300
#  - 1s - loss: 0.0070 - val_loss: 0.0055
# Epoch 157/300
#  - 1s - loss: 0.0054 - val_loss: 0.0031
# Epoch 158/300
#  - 1s - loss: 0.0019 - val_loss: 0.0069
# Epoch 159/300
#  - 1s - loss: 0.0013 - val_loss: 0.0010
# Epoch 160/300
#  - 1s - loss: 4.9603e-04 - val_loss: 0.0052
# Epoch 161/300
#  - 1s - loss: 0.0021 - val_loss: 0.0013
# Epoch 162/300
#  - 1s - loss: 0.0011 - val_loss: 7.8694e-04
# Epoch 163/300
#  - 1s - loss: 0.0012 - val_loss: 0.0034
# Epoch 164/300
#  - 1s - loss: 9.1084e-04 - val_loss: 0.0011
# Epoch 165/300
#  - 1s - loss: 7.2728e-04 - val_loss: 0.0021
# Epoch 166/300
#  - 1s - loss: 0.0015 - val_loss: 0.0019
# Epoch 167/300
#  - 1s - loss: 0.0017 - val_loss: 0.0012
# Epoch 168/300
#  - 1s - loss: 7.7161e-04 - val_loss: 9.2100e-04
# Epoch 169/300
#  - 1s - loss: 6.0606e-04 - val_loss: 0.0010
# Epoch 170/300
#  - 1s - loss: 5.6258e-04 - val_loss: 3.5785e-04
# Epoch 171/300
#  - 1s - loss: 6.3907e-04 - val_loss: 6.8994e-04
# Epoch 172/300
#  - 1s - loss: 8.1357e-04 - val_loss: 0.0034
# Epoch 173/300
#  - 1s - loss: 0.0035 - val_loss: 0.0023
# Epoch 174/300
#  - 1s - loss: 0.0023 - val_loss: 0.0016
# Epoch 175/300
#  - 1s - loss: 0.0014 - val_loss: 0.0029
# Epoch 176/300
#  - 1s - loss: 0.0013 - val_loss: 0.0017
# Epoch 177/300
#  - 1s - loss: 5.9175e-04 - val_loss: 7.3593e-04
# Epoch 178/300
#  - 1s - loss: 0.0011 - val_loss: 9.6427e-04
# Epoch 179/300
#  - 1s - loss: 4.2678e-04 - val_loss: 5.3633e-04
# Epoch 180/300
#  - 1s - loss: 4.3718e-04 - val_loss: 5.7377e-04
# Epoch 181/300
#  - 1s - loss: 5.1099e-04 - val_loss: 0.0016
# Epoch 182/300
#  - 1s - loss: 0.0013 - val_loss: 0.0012
# Epoch 183/300
#  - 1s - loss: 0.0013 - val_loss: 0.0042
# Epoch 184/300
#  - 1s - loss: 0.0017 - val_loss: 0.0024
# Epoch 185/300
#  - 1s - loss: 0.0015 - val_loss: 0.0036
# Epoch 186/300
#  - 1s - loss: 0.0018 - val_loss: 7.5356e-04
# Epoch 187/300
#  - 1s - loss: 6.2801e-04 - val_loss: 0.0012
# Epoch 188/300
#  - 1s - loss: 0.0013 - val_loss: 8.6820e-04
# Epoch 189/300
#  - 1s - loss: 0.0012 - val_loss: 0.0026
# Epoch 190/300
#  - 1s - loss: 0.0019 - val_loss: 0.0031
# Epoch 191/300
#  - 1s - loss: 0.0021 - val_loss: 7.0833e-04
# Epoch 192/300
#  - 1s - loss: 0.0011 - val_loss: 0.0041
# Epoch 193/300
#  - 1s - loss: 0.0029 - val_loss: 0.0028
# Epoch 194/300
#  - 1s - loss: 0.0016 - val_loss: 0.0036
# Epoch 195/300
#  - 1s - loss: 0.0021 - val_loss: 0.0018
# Epoch 196/300
#  - 1s - loss: 0.0013 - val_loss: 7.1688e-04
# Epoch 197/300
#  - 1s - loss: 0.0012 - val_loss: 9.2360e-04
# Epoch 198/300
#  - 1s - loss: 0.0015 - val_loss: 0.0015
# Epoch 199/300
#  - 1s - loss: 0.0011 - val_loss: 0.0083
# Epoch 200/300
#  - 1s - loss: 0.0040 - val_loss: 0.0069
# Epoch 201/300
#  - 1s - loss: 0.0024 - val_loss: 0.0089
# Epoch 202/300
#  - 1s - loss: 0.0030 - val_loss: 0.0067
# Epoch 203/300
#  - 1s - loss: 0.0038 - val_loss: 0.0039
# Epoch 204/300
#  - 1s - loss: 0.0016 - val_loss: 9.1969e-04
# Epoch 205/300
#  - 1s - loss: 0.0029 - val_loss: 0.0038
# Epoch 206/300
#  - 1s - loss: 0.0039 - val_loss: 0.0034
# Epoch 207/300
#  - 1s - loss: 0.0018 - val_loss: 0.0015
# Epoch 208/300
#  - 1s - loss: 0.0014 - val_loss: 8.8851e-04
# Epoch 209/300
#  - 1s - loss: 5.9944e-04 - val_loss: 0.0011
# Epoch 210/300
#  - 1s - loss: 7.8027e-04 - val_loss: 3.5360e-04
# Epoch 211/300
#  - 1s - loss: 3.9471e-04 - val_loss: 3.9582e-04
# Epoch 212/300
#  - 1s - loss: 4.3196e-04 - val_loss: 0.0012
# Epoch 213/300
#  - 1s - loss: 7.7277e-04 - val_loss: 0.0033
# Epoch 214/300
#  - 1s - loss: 0.0014 - val_loss: 5.6710e-04
# Epoch 215/300
#  - 1s - loss: 9.2095e-04 - val_loss: 4.5216e-04
# Epoch 216/300
#  - 1s - loss: 7.3856e-04 - val_loss: 0.0014
# Epoch 217/300
#  - 1s - loss: 0.0014 - val_loss: 9.8398e-04
# Epoch 218/300
#  - 1s - loss: 7.2020e-04 - val_loss: 6.7910e-04
# Epoch 219/300
#  - 1s - loss: 3.4994e-04 - val_loss: 5.0258e-04
# Epoch 220/300
#  - 1s - loss: 3.5684e-04 - val_loss: 0.0012
# Epoch 221/300
#  - 1s - loss: 6.6254e-04 - val_loss: 3.9161e-04
# Epoch 222/300
#  - 1s - loss: 2.9314e-04 - val_loss: 6.2188e-04
# Epoch 223/300
#  - 1s - loss: 9.3566e-04 - val_loss: 0.0013
# Epoch 224/300
#  - 1s - loss: 0.0010 - val_loss: 4.0279e-04
# Epoch 225/300
#  - 1s - loss: 8.0994e-04 - val_loss: 7.0344e-04
# Epoch 226/300
#  - 1s - loss: 7.6517e-04 - val_loss: 5.5643e-04
# Epoch 227/300
#  - 1s - loss: 9.9860e-04 - val_loss: 0.0026
# Epoch 228/300
#  - 1s - loss: 0.0021 - val_loss: 0.0016
# Epoch 229/300
#  - 1s - loss: 0.0011 - val_loss: 8.5183e-04
# Epoch 230/300
#  - 1s - loss: 7.1706e-04 - val_loss: 5.5005e-04
# Epoch 231/300
#  - 1s - loss: 3.0143e-04 - val_loss: 8.3599e-04
# Epoch 232/300
#  - 1s - loss: 3.9613e-04 - val_loss: 5.3094e-04
# Epoch 233/300
#  - 1s - loss: 3.5261e-04 - val_loss: 6.9172e-04
# Epoch 234/300
#  - 1s - loss: 5.3888e-04 - val_loss: 3.4308e-04
# Epoch 235/300
#  - 1s - loss: 3.6737e-04 - val_loss: 2.8679e-04
# Epoch 236/300
#  - 1s - loss: 2.3254e-04 - val_loss: 5.9098e-04
# Epoch 237/300
#  - 1s - loss: 6.2739e-04 - val_loss: 0.0014
# Epoch 238/300
#  - 1s - loss: 6.5477e-04 - val_loss: 0.0026
# Epoch 239/300
#  - 1s - loss: 0.0012 - val_loss: 0.0015
# Epoch 240/300
#  - 1s - loss: 9.7014e-04 - val_loss: 0.0036
# Epoch 241/300
#  - 1s - loss: 0.0017 - val_loss: 0.0104
# Epoch 242/300
#  - 1s - loss: 0.0045 - val_loss: 0.0021
# Epoch 243/300
#  - 1s - loss: 0.0017 - val_loss: 0.0017
# Epoch 244/300
#  - 1s - loss: 8.8094e-04 - val_loss: 7.1246e-04
# Epoch 245/300
#  - 1s - loss: 5.9459e-04 - val_loss: 0.0010
# Epoch 246/300
#  - 1s - loss: 4.0797e-04 - val_loss: 0.0013
# Epoch 247/300
#  - 1s - loss: 0.0013 - val_loss: 0.0038
# Epoch 248/300
#  - 1s - loss: 0.0017 - val_loss: 0.0022
# Epoch 249/300
#  - 1s - loss: 0.0022 - val_loss: 0.0029
# Epoch 250/300
#  - 1s - loss: 0.0015 - val_loss: 0.0057
# Epoch 251/300
#  - 1s - loss: 0.0020 - val_loss: 8.4648e-04
# Epoch 252/300
#  - 1s - loss: 0.0011 - val_loss: 4.5478e-04
# Epoch 253/300
#  - 1s - loss: 0.0011 - val_loss: 0.0022
# Epoch 254/300
#  - 1s - loss: 0.0013 - val_loss: 6.6971e-04
# Epoch 255/300
#  - 1s - loss: 4.1519e-04 - val_loss: 7.4449e-04
# Epoch 256/300
#  - 1s - loss: 6.1738e-04 - val_loss: 5.8381e-04
# Epoch 257/300
#  - 1s - loss: 9.3313e-04 - val_loss: 6.2592e-04
# Epoch 258/300
#  - 1s - loss: 6.1031e-04 - val_loss: 5.8260e-04
# Epoch 259/300
#  - 1s - loss: 7.0393e-04 - val_loss: 7.2398e-04
# Epoch 260/300
#  - 1s - loss: 6.4807e-04 - val_loss: 9.8535e-04
# Epoch 261/300
#  - 1s - loss: 7.0270e-04 - val_loss: 0.0038
# Epoch 262/300
#  - 1s - loss: 0.0026 - val_loss: 0.0038
# Epoch 263/300
#  - 1s - loss: 0.0019 - val_loss: 0.0014
# Epoch 264/300
#  - 1s - loss: 7.7224e-04 - val_loss: 0.0041
# Epoch 265/300
#  - 1s - loss: 0.0023 - val_loss: 0.0036
# Epoch 266/300
#  - 1s - loss: 0.0020 - val_loss: 0.0156
# Epoch 267/300
#  - 1s - loss: 0.0064 - val_loss: 0.0017
# Epoch 268/300
#  - 1s - loss: 0.0017 - val_loss: 0.0016
# Epoch 269/300
#  - 1s - loss: 9.9072e-04 - val_loss: 0.0047
# Epoch 270/300
#  - 1s - loss: 0.0035 - val_loss: 0.0017
# Epoch 271/300
#  - 1s - loss: 0.0013 - val_loss: 0.0017
# Epoch 272/300
#  - 1s - loss: 0.0013 - val_loss: 7.7734e-04
# Epoch 273/300
#  - 1s - loss: 0.0012 - val_loss: 0.0031
# Epoch 274/300
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch 275/300
#  - 1s - loss: 0.0012 - val_loss: 4.8526e-04
# Epoch 276/300
#  - 1s - loss: 0.0013 - val_loss: 0.0037
# Epoch 277/300
#  - 1s - loss: 0.0022 - val_loss: 0.0017
# Epoch 278/300
#  - 1s - loss: 0.0014 - val_loss: 0.0018
# Epoch 279/300
#  - 1s - loss: 0.0014 - val_loss: 0.0012
# Epoch 280/300
#  - 1s - loss: 0.0010 - val_loss: 0.0021
# Epoch 281/300
#  - 1s - loss: 7.0059e-04 - val_loss: 0.0019
# Epoch 282/300
#  - 1s - loss: 0.0011 - val_loss: 3.5294e-04
# Epoch 283/300
#  - 1s - loss: 5.3767e-04 - val_loss: 7.1312e-04
# Epoch 284/300
#  - 1s - loss: 8.5884e-04 - val_loss: 0.0010
# Epoch 285/300
#  - 1s - loss: 7.4010e-04 - val_loss: 0.0022
# Epoch 286/300
#  - 1s - loss: 0.0018 - val_loss: 0.0013
# Epoch 287/300
#  - 1s - loss: 0.0012 - val_loss: 3.5538e-04
# Epoch 288/300
#  - 1s - loss: 7.4700e-04 - val_loss: 3.8299e-04
# Epoch 289/300
#  - 1s - loss: 5.8776e-04 - val_loss: 0.0046
# Epoch 290/300
#  - 1s - loss: 0.0033 - val_loss: 0.0041
# Epoch 291/300
#  - 1s - loss: 0.0021 - val_loss: 0.0013
# Epoch 292/300
#  - 1s - loss: 9.2065e-04 - val_loss: 0.0011
# Epoch 293/300
#  - 1s - loss: 6.6841e-04 - val_loss: 4.0097e-04
# Epoch 294/300
#  - 1s - loss: 4.8373e-04 - val_loss: 3.6114e-04
# Epoch 295/300
#  - 1s - loss: 2.4061e-04 - val_loss: 3.4330e-04
# Epoch 296/300
#  - 1s - loss: 3.8485e-04 - val_loss: 8.7459e-04
# Epoch 297/300
#  - 1s - loss: 5.1576e-04 - val_loss: 5.4664e-04
# Epoch 298/300
#  - 1s - loss: 2.4078e-04 - val_loss: 5.9381e-04
# Epoch 299/300
#  - 1s - loss: 4.8820e-04 - val_loss: 4.1978e-04
# Epoch 300/300
#  - 1s - loss: 4.3568e-04 - val_loss: 7.8265e-04
# loss: 580320977387.52
# 정답(original): [   0.  -400.    50.     0.4]
# 예측값(original): [1.2688094  0.29564643 1.638722   0.40615872]
# 6.652107185189327
# 42068267.63013627
# (2800, 4)
# 2.411139556749588
# 15.820191800594325
# -12.306591868400579
